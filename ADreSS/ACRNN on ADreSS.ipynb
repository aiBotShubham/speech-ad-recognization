# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
data_path = 'adress.pkl'
checkpoint = 'checkpoint/'
model_name = 'model.ckpt'
pred_name = 'pred0.pkl'
checkpoint_secs = 60

dropout_conv = 1
dropout_linear = 1
dropout_lstm = 1
dropout_fully1 = 1
dropout_fully2 = 1

#decayed_learning rate
decay_rate = 0.99
beta1 = 0.9
beta2 = 0.999

#Moving Average
decay_steps = 570
momentum = 0.99
num_epoch = 1000
relu_clip =  20.0

# Adam optimizer (http://arxiv.org/abs/1412.6980) parameters

adam_beta1 = 0.9
adam_beta2 = 0.999
epsilon =  1e-8
learning_rate =   0.0001

# Batch sizes


train_batch_size = 40
valid_batch_size = 40
test_batch_size =  40
batch_size =  40
save_steps =   10

image_height =   300
image_width = 40
image_channel = 3

linear_num =  786
seq_len =   150
cell_num = 128
hidden1 = 64
hidden2 =  4
attention_size =   1
# attention = False

def attention(inputs, attention_size, time_major=False, return_alphas=False):
    """
    Attention mechanism layer which reduces RNN/Bi-RNN outputs with Attention vector.

    The idea was proposed in the article by Z. Yang et al., "Hierarchical Attention Networks
     for Document Classification", 2016: http://www.aclweb.org/anthology/N16-1174.
    Variables notation is also inherited from the article
    
    Args:
        inputs: The Attention inputs.
            Matches outputs of RNN/Bi-RNN layer (not final state):
                In case of RNN, this must be RNN outputs `Tensor`:
                    If time_major == False (default), this must be a tensor of shape:
                        `[batch_size, max_time, cell.output_size]`.
                    If time_major == True, this must be a tensor of shape:
                        `[max_time, batch_size, cell.output_size]`.
                In case of Bidirectional RNN, this must be a tuple (outputs_fw, outputs_bw) containing the forward and
                the backward RNN outputs `Tensor`.
                    If time_major == False (default),
                        outputs_fw is a `Tensor` shaped:
                        `[batch_size, max_time, cell_fw.output_size]`
                        and outputs_bw is a `Tensor` shaped:
                        `[batch_size, max_time, cell_bw.output_size]`.
                    If time_major == True,
                        outputs_fw is a `Tensor` shaped:
                        `[max_time, batch_size, cell_fw.output_size]`
                        and outputs_bw is a `Tensor` shaped:
                        `[max_time, batch_size, cell_bw.output_size]`.
        attention_size: Linear size of the Attention weights.
        time_major: The shape format of the `inputs` Tensors.
            If true, these `Tensors` must be shaped `[max_time, batch_size, depth]`.
            If false, these `Tensors` must be shaped `[batch_size, max_time, depth]`.
            Using `time_major = True` is a bit more efficient because it avoids
            transposes at the beginning and end of the RNN calculation.  However,
            most TensorFlow data is batch-major, so by default this function
            accepts input and emits output in batch-major form.
        return_alphas: Whether to return attention coefficients variable along with layer's output.
            Used for visualization purpose.
    Returns:
        The Attention output `Tensor`.
        In case of RNN, this will be a `Tensor` shaped:
            `[batch_size, cell.output_size]`.
        In case of Bidirectional RNN, this will be a `Tensor` shaped:
            `[batch_size, cell_fw.output_size + cell_bw.output_size]`.
    """

    if isinstance(inputs, tuple):
        # In case of Bi-RNN, concatenate the forward and the backward RNN outputs.
        inputs = tf.concat(inputs, 2)

    if time_major:
        # (T,B,D) => (B,T,D)
        inputs = tf.array_ops.transpose(inputs, [1, 0, 2])

    hidden_size = inputs.shape[2].value  # D value - hidden size of the RNN layer

    # Trainable parameters
    W_omega = tf.Variable(tf.random_normal([hidden_size, attention_size], stddev=0.1))
    b_omega = tf.Variable(tf.random_normal([attention_size], stddev=0.1))
    u_omega = tf.Variable(tf.random_normal([attention_size], stddev=0.1))

    # Applying fully connected layer with non-linear activation to each of the B*T timestamps;
    #  the shape of `v` is (B,T,D)*(D,A)=(B,T,A), where A=attention_size
    #v = tf.tanh(tf.tensordot(inputs, W_omega, axes=1) + b_omega)
    v = tf.sigmoid(tf.tensordot(inputs, W_omega, axes=1) + b_omega)
    # For each of the timestamps its vector of size A from `v` is reduced with `u` vector
    vu = tf.tensordot(v, u_omega, axes=1)   # (B,T) shape
    alphas = tf.nn.softmax(vu)              # (B,T) shape also

    # Output of (Bi-)RNN is reduced with attention vector; the result has (B,D) shape
    output = tf.reduce_sum(inputs * tf.expand_dims(alphas, -1), 1)

    if not return_alphas:
        return output
    else:
        return output, alphas

# %%
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()
tf.disable_v2_behavior()

epsilon = 1e-3

def leaky_relu(x, leakiness=0.0):
    return tf.where(tf.less(x, 0.0), leakiness * x, x, name='leaky_relu')

def batch_norm_wrapper(inputs, is_training, decay = 0.999):

    scale = tf.Variable(tf.ones([inputs.get_shape()[-1]]))
    beta = tf.Variable(tf.zeros([inputs.get_shape()[-1]]))
    pop_mean = tf.Variable(tf.zeros([inputs.get_shape()[-1]]), trainable=False)
    pop_var = tf.Variable(tf.ones([inputs.get_shape()[-1]]), trainable=False)

    if is_training is not None:
        batch_mean, batch_var = tf.nn.moments(inputs,[0])
        train_mean = tf.assign(pop_mean,
                               pop_mean * decay + batch_mean * (1 - decay))
        train_var = tf.assign(pop_var,
                              pop_var * decay + batch_var * (1 - decay))
        with tf.control_dependencies([train_mean, train_var]):
            return tf.nn.batch_normalization(inputs,
                batch_mean, batch_var, beta, scale, epsilon)
    else:
        return tf.nn.batch_normalization(inputs,
            pop_mean, pop_var, beta, scale, epsilon)

def acrnn(inputs, num_classes=2,
                  is_training=True,
                  L1=128,
                  L2=256,
                  cell_units=128,
                  num_linear=768,
                  p=10,
                  time_step=150,
                  F1=64,
                  dropout_keep_prob=1):
    
    global ndims
    layer1_filter = tf.get_variable('layer1_filter', shape=[5, 3, 3, L1], dtype=tf.float32, 
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    layer1_bias = tf.get_variable('layer1_bias', shape=[L1], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer1_stride = [1, 1, 1, 1]
    layer2_filter = tf.get_variable('layer2_filter', shape=[5, 3, L1, L2], dtype=tf.float32, 
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    layer2_bias = tf.get_variable('layer2_bias', shape=[L2], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer2_stride = [1, 1, 1, 1]
    layer3_filter = tf.get_variable('layer3_filter', shape=[5, 3, L2, L2], dtype=tf.float32, 
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    layer3_bias = tf.get_variable('layer3_bias', shape=[L2], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer3_stride = [1, 1, 1, 1]
    layer4_filter = tf.get_variable('layer4_filter', shape=[5, 3, L2, L2], dtype=tf.float32, 
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    layer4_bias = tf.get_variable('layer4_bias', shape=[L2], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer4_stride = [1, 1, 1, 1]
    layer5_filter = tf.get_variable('layer5_filter', shape=[5, 3, L2, L2], dtype=tf.float32, 
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    layer5_bias = tf.get_variable('layer5_bias', shape=[L2], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer5_stride = [1, 1, 1, 1]
    layer6_filter = tf.get_variable('layer6_filter', shape=[5, 3, L2, L2], dtype=tf.float32, 
                                    initializer=tf.compat.v1.truncated_normal_initializer(stddev=0.1))
    layer6_bias = tf.get_variable('layer6_bias', shape=[L2], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer6_stride = [1, 1, 1, 1]
    
    linear1_weight = tf.get_variable('linear1_weight', shape=[p*L2,num_linear], dtype=tf.float32,
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    linear1_bias = tf.get_variable('linear1_bias', shape=[num_linear], dtype=tf.float32,
                                  initializer=tf.compat.v1.constant_initializer(0.1))
 
    fully1_weight = tf.get_variable('fully1_weight', shape=[2*cell_units,F1], dtype=tf.float32,
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    fully1_bias = tf.get_variable('fully1_bias', shape=[F1], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    fully2_weight = tf.get_variable('fully2_weight', shape=[F1,num_classes], dtype=tf.float32,
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    fully2_bias = tf.get_variable('fully2_bias', shape=[num_classes], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    
    layer1 = tf.nn.conv2d(inputs, layer1_filter, layer1_stride, padding='SAME')
    layer1 = tf.nn.bias_add(layer1,layer1_bias)
    layer1 = leaky_relu(layer1, 0.01)
    layer1 = tf.nn.max_pool(layer1,ksize=[1, 2, 4, 1], strides=[1, 2, 4, 1], padding='VALID', name='max_pool')
    layer1 = tf.layers.dropout(layer1, rate = 1 - keep_prob)
    
    layer2 = tf.nn.conv2d(layer1, layer2_filter, layer2_stride, padding='SAME')
    layer2 = tf.nn.bias_add(layer2,layer2_bias)
    layer2 = leaky_relu(layer2, 0.01)
    layer2 = tf.layers.dropout(layer2, rate = 1 - keep_prob)
    
    layer3 = tf.nn.conv2d(layer2, layer3_filter, layer3_stride, padding='SAME')
    layer3 = tf.nn.bias_add(layer3,layer3_bias)
    layer3 = leaky_relu(layer3, 0.01)
    layer3 = tf.layers.dropout(layer3, rate = 1 - keep_prob)
    
    layer4 = tf.nn.conv2d(layer3, layer4_filter, layer4_stride, padding='SAME')
    layer4 = tf.nn.bias_add(layer4,layer4_bias)
    layer4 = leaky_relu(layer4, 0.01)
    layer4 = tf.layers.dropout(layer4, rate = 1 - keep_prob)
    
    layer5 = tf.nn.conv2d(layer4, layer5_filter, layer5_stride, padding='SAME')
    layer5 = tf.nn.bias_add(layer5,layer5_bias)
    layer5 = leaky_relu(layer5, 0.01)    
    layer5 = tf.layers.dropout(layer5, rate = 1 - keep_prob)

    layer6 = tf.nn.conv2d(layer5, layer6_filter, layer6_stride, padding='SAME')
    layer6 = tf.nn.bias_add(layer6,layer6_bias)
    layer6 = leaky_relu(layer6, 0.01)    
    layer6 = tf.layers.dropout(layer6, rate = 1 - keep_prob)
    
    layer6 = tf.reshape(layer6,[-1,time_step,L2*p])
    layer6 = tf.reshape(layer6, [-1,p*L2])
    
    linear1 = tf.matmul(layer6,linear1_weight) + linear1_bias
    linear1 = batch_norm_wrapper(linear1,is_training)
    linear1 = leaky_relu(linear1, 0.01)
    #linear1 = batch_norm_wrapper(linear1,is_training)
    linear1 = tf.reshape(linear1, [-1, time_step, num_linear])
    
    
    
    # Define lstm cells with tensorflow
    # Forward direction cell
    gru_fw_cell1 = tf.nn.rnn_cell.BasicLSTMCell(cell_units, forget_bias=1.0)
    # Backward direction cell
    gru_bw_cell1 = tf.nn.rnn_cell.BasicLSTMCell(cell_units, forget_bias=1.0)
    
    # Now we feed `layer_3` into the LSTM BRNN cell and obtain the LSTM BRNN output.
    outputs1, output_states1 = tf.nn.bidirectional_dynamic_rnn(cell_fw=gru_fw_cell1,
                                                             cell_bw=gru_bw_cell1,
                                                             inputs= linear1,
                                                             dtype=tf.float32,
                                                             time_major=False,
                                                             scope='LSTM1')

    # Attention layer
    gru, alphas = attention(outputs1, 1, return_alphas=True)
    
    
    fully1 = tf.matmul(gru,fully1_weight) + fully1_bias
    fully1 = leaky_relu(fully1, 0.01)
    fully1 = tf.nn.dropout(fully1, dropout_keep_prob)
    
    
    Ylogits = tf.matmul(fully1, fully2_weight) + fully2_bias
    #Ylogits = tf.nn.softmax(Ylogits)
    return Ylogits
# Out:
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def load_data(in_dir):
    f = open(in_dir,'rb')
    train_data,train_label,test_data,test_label,valid_data,valid_label,pernums_valid = pickle.load(f)
    return train_data,train_label,test_data,test_label,valid_data,valid_label,pernums_valid

def dense_to_one_hot(labels_dense, num_classes = 2):
    """Convert class labels from scalars to one-hot vectors."""
    num_labels = labels_dense.shape[0]
    index_offset = np.arange(num_labels) * num_classes
    labels_one_hot = np.zeros((num_labels, num_classes))
    labels_one_hot.flat[index_offset + labels_dense.ravel()] = 1
    return labels_one_hot

# %%
import numpy as np
import pickle
from sklearn.metrics import recall_score as recall
from sklearn.metrics import confusion_matrix as confusion
import os

num_classes = 2
is_adam = True
dropout_keep_prob = 1
data_path = 'adress.pkl'
checkpoint = 'checkpoint/'

train_data,train_label,test_data,test_label,valid_data,valid_label,pernums_valid = load_data(data_path)
# Valid_label = valid_label
vnum = 297

train_label = dense_to_one_hot(train_label,num_classes)
valid_label = dense_to_one_hot(valid_label,num_classes)
# valid_label = dense_to_one_hot(valid_label,num_classes)

valid_size = valid_data.shape[0]
dataset_size = train_data.shape[0]
vnum = valid_data.shape[0]
best_valid_uw = 0



X = tf.compat.v1.placeholder(tf.float32, shape=[None, image_height,image_width,image_channel])
Y = tf.compat.v1.placeholder(tf.int32, shape=[None, num_classes])

is_training = tf.compat.v1.placeholder(tf.bool)
lr = tf.compat.v1.placeholder(tf.float32)
keep_prob = tf.compat.v1.placeholder(tf.float32)

Ylogits = acrnn(X, is_training=is_training, dropout_keep_prob=keep_prob)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels =  Y, logits =  Ylogits)
cost = tf.reduce_mean(cross_entropy)
var_trainable_op = tf.trainable_variables()
if is_adam:
    # not apply gradient clipping
    train_op = tf.train.AdamOptimizer(lr).minimize(cost)            
else:
    # apply gradient clipping
    grads, _ = tf.clip_by_global_norm(tf.gradients(cost, var_trainable_op), 5)
    opti = tf.train.AdamOptimizer(lr)
    train_op = opti.apply_gradients(zip(grads, var_trainable_op))
    
correct_pred = tf.equal(tf.argmax(Ylogits, 1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
saver=tf.train.Saver(tf.global_variables())
init = tf.global_variables_initializer()

epocs = []
validation_accuracy = []
training_accuracy = []
with tf.Session() as sess:
    sess.run(init)
    for i in range(num_epoch):
        #learning_rate = FLAGS.learning_rate            
        start = (i * batch_size) % dataset_size
        end = min(start+batch_size, dataset_size)
        [_,tcost,tracc] = sess.run([train_op,cost,accuracy], feed_dict={X:train_data[start:end,:,:,:], Y:train_label[start:end,:],
                                        is_training:True, keep_prob:dropout_keep_prob, lr:learning_rate})
        if i % 5 == 0:
            #for valid data
            valid_iter = divmod((valid_size),batch_size)[0]
            y_pred_valid = np.empty((valid_size,num_classes),dtype=np.float32)
            y_valid = np.empty((vnum,2),dtype=np.float32)
            index = 0
            cost_valid = 0
            if(valid_size < batch_size):
                loss, y_pred_valid = sess.run([cross_entropy,Ylogits],feed_dict = {X:valid_data, Y:valid_label,is_training:False, keep_prob:1})
                cost_valid = cost_valid + np.sum(loss)
            for v in range(valid_iter):
                v_begin = v*batch_size
                v_end = (v+1)*batch_size
                if(v == valid_iter-1):
                    if(v_end < valid_size):
                        v_end = valid_size
                loss, y_pred_valid[v_begin:v_end,:] = sess.run([cross_entropy,Ylogits],feed_dict = {X:valid_data[v_begin:v_end],Y:valid_label[v_begin:v_end],is_training:False, keep_prob:1})
                cost_valid = cost_valid + np.sum(loss)
            cost_valid = cost_valid/valid_size
            
#             for s in range(vnum):
#                 y_valid[s,:] = np.max(y_pred_valid[index:index+ pernums_valid[s][0],:],0)
#                 index = index + pernums_valid[s][0]

            valid_acc_uw = recall(np.argmax(valid_label,1),np.argmax(y_valid,1),average='macro')
            valid_conf = confusion(np.argmax(valid_label, 1),np.argmax(y_valid,1))
            
            if valid_acc_uw > best_valid_uw:
                best_valid_uw = valid_acc_uw
                best_valid_conf = valid_conf
                saver.save(sess, os.path.join(checkpoint, model_name), global_step = i+1)
            
            print ("*****************************************************************")
            print ("Epoch: %05d" %(i+1))
            epocs.append(i+1)
            print ("Training cost: %2.3g" %tcost)   
            print ("Training accuracy: %3.4g" %tracc) 
            training_accuracy.append(tracc)
            print ("Valid cost: %2.3g" %cost_valid)
            print ("Valid_UA: %3.4g" %valid_acc_uw) 
            validation_accuracy.append(valid_acc_uw)
            print ("Best valid_UA: %3.4g" %best_valid_uw) 
            print ('Valid Confusion Matrix:["cc","cd"]')
            print (valid_conf)
            print ('Best Valid Confusion Matrix:["cc","cd"]')
            print (best_valid_conf)
            print ("*****************************************************************" )
# Out:
# WARNING:tensorflow:From C:\Users\Asus\AppData\Local\Temp/ipykernel_12500/2699534420.py:136: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\tensorflow\python\ops\rnn.py:437: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\keras\layers\legacy_rnn\rnn_cell_impl.py:760: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\tensorflow\python\util\dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# C:\Users\Asus\AppData\Local\Temp/ipykernel_12500/2699534420.py:91: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   layer1 = tf.layers.dropout(layer1, rate = 1 - keep_prob)
# C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\keras\legacy_tf_layers\core.py:413: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   return layer.apply(inputs, training=training)
# C:\Users\Asus\AppData\Local\Temp/ipykernel_12500/2699534420.py:96: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   layer2 = tf.layers.dropout(layer2, rate = 1 - keep_prob)
# C:\Users\Asus\AppData\Local\Temp/ipykernel_12500/2699534420.py:101: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   layer3 = tf.layers.dropout(layer3, rate = 1 - keep_prob)
# C:\Users\Asus\AppData\Local\Temp/ipykernel_12500/2699534420.py:106: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   layer4 = tf.layers.dropout(layer4, rate = 1 - keep_prob)
# C:\Users\Asus\AppData\Local\Temp/ipykernel_12500/2699534420.py:111: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   layer5 = tf.layers.dropout(layer5, rate = 1 - keep_prob)
# C:\Users\Asus\AppData\Local\Temp/ipykernel_12500/2699534420.py:116: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   layer6 = tf.layers.dropout(layer6, rate = 1 - keep_prob)
# C:\Users\Asus\AppData\Local\Temp/ipykernel_12500/2699534420.py:131: UserWarning: `tf.nn.rnn_cell.BasicLSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   gru_fw_cell1 = tf.nn.rnn_cell.BasicLSTMCell(cell_units, forget_bias=1.0)
# C:\Users\Asus\AppData\Local\Temp/ipykernel_12500/2699534420.py:133: UserWarning: `tf.nn.rnn_cell.BasicLSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   gru_bw_cell1 = tf.nn.rnn_cell.BasicLSTMCell(cell_units, forget_bias=1.0)
# C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\keras\layers\legacy_rnn\rnn_cell_impl.py:754: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   self._kernel = self.add_variable(
# C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\keras\layers\legacy_rnn\rnn_cell_impl.py:757: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   self._bias = self.add_variable(
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\tensorflow\python\util\dispatch.py:1082: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# *****************************************************************
# Epoch: 00001
# Training cost: 0.697
# Training accuracy: 0.525
# Valid cost: 0.744
# Valid_UA: 0.5
# Best valid_UA: 0.5
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# *****************************************************************
# *****************************************************************
# Epoch: 00006
# Training cost: 0.758
# Training accuracy: 0.45
# Valid cost: 0.696
# Valid_UA: 0.5031
# Best valid_UA: 0.5031
# Valid Confusion Matrix:["cc","cd"]
# [[  4 146]
#  [  3 144]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[  4 146]
#  [  3 144]]
# *****************************************************************
# *****************************************************************
# Epoch: 00011
# Training cost: 0.696
# Training accuracy: 0.525
# Valid cost: 0.69
# Valid_UA: 0.5591
# Best valid_UA: 0.5591
# Valid Confusion Matrix:["cc","cd"]
# [[ 31 119]
#  [ 13 134]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 31 119]
#  [ 13 134]]
# *****************************************************************
# *****************************************************************
# Epoch: 00016
# Training cost: 0.668
# Training accuracy: 0.6
# Valid cost: 0.704
# Valid_UA: 0.5
# Best valid_UA: 0.5591
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 31 119]
#  [ 13 134]]
# *****************************************************************
# *****************************************************************
# Epoch: 00021
# Training cost: 0.671
# Training accuracy: 0.55
# Valid cost: 0.676
# Valid_UA: 0.5594
# Best valid_UA: 0.5594
# Valid Confusion Matrix:["cc","cd"]
# [[ 27 123]
#  [  9 138]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 27 123]
#  [  9 138]]
# *****************************************************************
# *****************************************************************
# Epoch: 00026
# Training cost: 0.679
# Training accuracy: 0.6
# Valid cost: 0.68
# Valid_UA: 0.5
# Best valid_UA: 0.5594
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 27 123]
#  [  9 138]]
# *****************************************************************
# *****************************************************************
# Epoch: 00031
# Training cost: 0.648
# Training accuracy: 0.6
# Valid cost: 0.675
# Valid_UA: 0.5
# Best valid_UA: 0.5594
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 27 123]
#  [  9 138]]
# *****************************************************************
# *****************************************************************
# Epoch: 00036
# Training cost: 0.663
# Training accuracy: 0.525
# Valid cost: 0.686
# Valid_UA: 0.5748
# Best valid_UA: 0.5748
# Valid Confusion Matrix:["cc","cd"]
# [[ 50 100]
#  [ 27 120]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 50 100]
#  [ 27 120]]
# *****************************************************************
# *****************************************************************
# Epoch: 00041
# Training cost: 0.614
# Training accuracy: 0.7
# Valid cost: 0.696
# Valid_UA: 0.5
# Best valid_UA: 0.5748
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 50 100]
#  [ 27 120]]
# *****************************************************************
# *****************************************************************
# Epoch: 00046
# Training cost: 0.716
# Training accuracy: 0.475
# Valid cost: 0.669
# Valid_UA: 0.5
# Best valid_UA: 0.5748
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 50 100]
#  [ 27 120]]
# *****************************************************************
# *****************************************************************
# Epoch: 00051
# Training cost: 0.642
# Training accuracy: 0.6
# Valid cost: 0.667
# Valid_UA: 0.5682
# Best valid_UA: 0.5748
# Valid Confusion Matrix:["cc","cd"]
# [[ 47 103]
#  [ 26 121]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 50 100]
#  [ 27 120]]
# *****************************************************************
# WARNING:tensorflow:From C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\tensorflow\python\training\saver.py:1052: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# *****************************************************************
# Epoch: 00056
# Training cost: 0.679
# Training accuracy: 0.5
# Valid cost: 0.681
# Valid_UA: 0.6061
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00061
# Training cost: 0.752
# Training accuracy: 0.475
# Valid cost: 0.669
# Valid_UA: 0.5154
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[123  27]
#  [116  31]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00066
# Training cost: 0.745
# Training accuracy: 0.475
# Valid cost: 0.704
# Valid_UA: 0.4893
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[108  42]
#  [109  38]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00071
# Training cost: 0.632
# Training accuracy: 0.65
# Valid cost: 0.68
# Valid_UA: 0.5
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00076
# Training cost: 0.685
# Training accuracy: 0.45
# Valid cost: 0.671
# Valid_UA: 0.5608
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[106  44]
#  [ 86  61]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00081
# Training cost: 0.688
# Training accuracy: 0.525
# Valid cost: 0.663
# Valid_UA: 0.5
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00086
# Training cost: 0.701
# Training accuracy: 0.525
# Valid cost: 0.672
# Valid_UA: 0.5034
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [146   1]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00091
# Training cost: 0.662
# Training accuracy: 0.6
# Valid cost: 0.665
# Valid_UA: 0.5
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00096
# Training cost: 0.696
# Training accuracy: 0.55
# Valid cost: 0.67
# Valid_UA: 0.4879
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[128  22]
#  [129  18]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00101
# Training cost: 0.609
# Training accuracy: 0.625
# Valid cost: 0.664
# Valid_UA: 0.5
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00106
# Training cost: 0.626
# Training accuracy: 0.675
# Valid cost: 0.662
# Valid_UA: 0.5262
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[115  35]
#  [105  42]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00111
# Training cost: 0.62
# Training accuracy: 0.65
# Valid cost: 0.657
# Valid_UA: 0.5
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00116
# Training cost: 0.711
# Training accuracy: 0.525
# Valid cost: 0.674
# Valid_UA: 0.5068
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [145   2]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00121
# Training cost: 0.719
# Training accuracy: 0.525
# Valid cost: 0.658
# Valid_UA: 0.4839
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[136  14]
#  [138   9]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00126
# Training cost: 0.772
# Training accuracy: 0.4
# Valid cost: 0.682
# Valid_UA: 0.5953
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[ 49 101]
#  [ 20 127]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00131
# Training cost: 0.696
# Training accuracy: 0.525
# Valid cost: 0.674
# Valid_UA: 0.5
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00136
# Training cost: 0.723
# Training accuracy: 0.425
# Valid cost: 0.666
# Valid_UA: 0.4861
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[104  46]
#  [106  41]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00141
# Training cost: 0.673
# Training accuracy: 0.525
# Valid cost: 0.658
# Valid_UA: 0.5
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00146
# Training cost: 0.721
# Training accuracy: 0.475
# Valid cost: 0.665
# Valid_UA: 0.4877
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[131  19]
#  [132  15]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00151
# Training cost: 0.654
# Training accuracy: 0.625
# Valid cost: 0.664
# Valid_UA: 0.4969
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[96 54]
#  [95 52]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00156
# Training cost: 0.658
# Training accuracy: 0.45
# Valid cost: 0.661
# Valid_UA: 0.4988
# Best valid_UA: 0.6061
# Valid Confusion Matrix:["cc","cd"]
# [[117  33]
#  [115  32]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[91 59]
#  [58 89]]
# *****************************************************************
# *****************************************************************
# Epoch: 00161
# Training cost: 0.672
# Training accuracy: 0.55
# Valid cost: 0.67
# Valid_UA: 0.6087
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00166
# Training cost: 0.613
# Training accuracy: 0.675
# Valid cost: 0.651
# Valid_UA: 0.5752
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[ 45 105]
#  [ 22 125]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00171
# Training cost: 0.661
# Training accuracy: 0.625
# Valid cost: 0.657
# Valid_UA: 0.5852
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[ 47 103]
#  [ 21 126]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00176
# Training cost: 0.657
# Training accuracy: 0.65
# Valid cost: 0.667
# Valid_UA: 0.5484
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[89 61]
#  [73 74]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00181
# Training cost: 0.627
# Training accuracy: 0.675
# Valid cost: 0.655
# Valid_UA: 0.5
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00186
# Training cost: 0.735
# Training accuracy: 0.5
# Valid cost: 0.678
# Valid_UA: 0.4576
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[124  26]
#  [134  13]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00191
# Training cost: 0.706
# Training accuracy: 0.525
# Valid cost: 0.661
# Valid_UA: 0.5
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00196
# Training cost: 0.706
# Training accuracy: 0.575
# Valid cost: 0.652
# Valid_UA: 0.5
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00201
# Training cost: 0.643
# Training accuracy: 0.6
# Valid cost: 0.65
# Valid_UA: 0.5016
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[126  24]
#  [123  24]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00206
# Training cost: 0.713
# Training accuracy: 0.5
# Valid cost: 0.654
# Valid_UA: 0.5741
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[ 61  89]
#  [ 38 109]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00211
# Training cost: 0.669
# Training accuracy: 0.525
# Valid cost: 0.662
# Valid_UA: 0.5
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00216
# Training cost: 0.646
# Training accuracy: 0.575
# Valid cost: 0.644
# Valid_UA: 0.5
# Best valid_UA: 0.6087
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[102  48]
#  [ 68  79]]
# *****************************************************************
# *****************************************************************
# Epoch: 00221
# Training cost: 0.636
# Training accuracy: 0.6
# Valid cost: 0.646
# Valid_UA: 0.6202
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00226
# Training cost: 0.624
# Training accuracy: 0.725
# Valid cost: 0.635
# Valid_UA: 0.5034
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [146   1]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00231
# Training cost: 0.702
# Training accuracy: 0.525
# Valid cost: 0.641
# Valid_UA: 0.5
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00236
# Training cost: 0.632
# Training accuracy: 0.65
# Valid cost: 0.646
# Valid_UA: 0.4967
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[149   1]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00241
# Training cost: 0.62
# Training accuracy: 0.625
# Valid cost: 0.646
# Valid_UA: 0.5
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00246
# Training cost: 0.617
# Training accuracy: 0.65
# Valid cost: 0.652
# Valid_UA: 0.5
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00251
# Training cost: 0.636
# Training accuracy: 0.675
# Valid cost: 0.67
# Valid_UA: 0.5173
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[146   4]
#  [138   9]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00256
# Training cost: 0.683
# Training accuracy: 0.575
# Valid cost: 0.655
# Valid_UA: 0.4958
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[112  38]
#  [111  36]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00261
# Training cost: 0.647
# Training accuracy: 0.675
# Valid cost: 0.65
# Valid_UA: 0.5008
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[88 62]
#  [86 61]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00266
# Training cost: 0.687
# Training accuracy: 0.525
# Valid cost: 0.649
# Valid_UA: 0.4941
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[136  14]
#  [135  12]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00271
# Training cost: 0.688
# Training accuracy: 0.5
# Valid cost: 0.653
# Valid_UA: 0.5002
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[97 53]
#  [95 52]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00276
# Training cost: 0.666
# Training accuracy: 0.55
# Valid cost: 0.641
# Valid_UA: 0.6124
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[98 52]
#  [63 84]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00281
# Training cost: 0.631
# Training accuracy: 0.5
# Valid cost: 0.646
# Valid_UA: 0.5
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00286
# Training cost: 0.628
# Training accuracy: 0.65
# Valid cost: 0.632
# Valid_UA: 0.5956
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[ 45 105]
#  [ 16 131]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00291
# Training cost: 0.613
# Training accuracy: 0.675
# Valid cost: 0.643
# Valid_UA: 0.5
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00296
# Training cost: 0.555
# Training accuracy: 0.825
# Valid cost: 0.643
# Valid_UA: 0.5
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00301
# Training cost: 0.636
# Training accuracy: 0.65
# Valid cost: 0.644
# Valid_UA: 0.5001
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[149   1]
#  [146   1]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00306
# Training cost: 0.568
# Training accuracy: 0.75
# Valid cost: 0.663
# Valid_UA: 0.4992
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[112  38]
#  [110  37]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00311
# Training cost: 0.585
# Training accuracy: 0.725
# Valid cost: 0.65
# Valid_UA: 0.5385
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[134  16]
#  [120  27]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00316
# Training cost: 0.661
# Training accuracy: 0.625
# Valid cost: 0.635
# Valid_UA: 0.5744
# Best valid_UA: 0.6202
# Valid Confusion Matrix:["cc","cd"]
# [[ 56  94]
#  [ 33 114]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 83  67]
#  [ 46 101]]
# *****************************************************************
# *****************************************************************
# Epoch: 00321
# Training cost: 0.639
# Training accuracy: 0.725
# Valid cost: 0.632
# Valid_UA: 0.6378
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00326
# Training cost: 0.653
# Training accuracy: 0.6
# Valid cost: 0.631
# Valid_UA: 0.5001
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[149   1]
#  [146   1]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00331
# Training cost: 0.682
# Training accuracy: 0.55
# Valid cost: 0.644
# Valid_UA: 0.5
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00336
# Training cost: 0.637
# Training accuracy: 0.6
# Valid cost: 0.627
# Valid_UA: 0.5
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00341
# Training cost: 0.621
# Training accuracy: 0.525
# Valid cost: 0.627
# Valid_UA: 0.4688
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[108  42]
#  [115  32]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00346
# Training cost: 0.68
# Training accuracy: 0.475
# Valid cost: 0.615
# Valid_UA: 0.507
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[97 53]
#  [93 54]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00351
# Training cost: 0.619
# Training accuracy: 0.65
# Valid cost: 0.63
# Valid_UA: 0.5
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00356
# Training cost: 0.517
# Training accuracy: 0.775
# Valid cost: 0.628
# Valid_UA: 0.5
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00361
# Training cost: 0.623
# Training accuracy: 0.65
# Valid cost: 0.631
# Valid_UA: 0.5168
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[103  47]
#  [ 96  51]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00366
# Training cost: 0.612
# Training accuracy: 0.65
# Valid cost: 0.636
# Valid_UA: 0.4718
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[115  35]
#  [121  26]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00371
# Training cost: 0.6
# Training accuracy: 0.625
# Valid cost: 0.64
# Valid_UA: 0.4984
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[123  27]
#  [121  26]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00376
# Training cost: 0.572
# Training accuracy: 0.75
# Valid cost: 0.63
# Valid_UA: 0.5
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00381
# Training cost: 0.646
# Training accuracy: 0.65
# Valid cost: 0.627
# Valid_UA: 0.5
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00386
# Training cost: 0.629
# Training accuracy: 0.65
# Valid cost: 0.621
# Valid_UA: 0.5
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00391
# Training cost: 0.655
# Training accuracy: 0.625
# Valid cost: 0.634
# Valid_UA: 0.489
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[111  39]
#  [112  35]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00396
# Training cost: 0.624
# Training accuracy: 0.6
# Valid cost: 0.621
# Valid_UA: 0.6222
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[104  46]
#  [ 66  81]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00401
# Training cost: 0.639
# Training accuracy: 0.575
# Valid cost: 0.619
# Valid_UA: 0.4937
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[143   7]
#  [142   5]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00406
# Training cost: 0.637
# Training accuracy: 0.575
# Valid cost: 0.61
# Valid_UA: 0.5254
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[127  23]
#  [117  30]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00411
# Training cost: 0.682
# Training accuracy: 0.625
# Valid cost: 0.636
# Valid_UA: 0.6154
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[ 54  96]
#  [ 19 128]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00416
# Training cost: 0.709
# Training accuracy: 0.55
# Valid cost: 0.631
# Valid_UA: 0.5
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00421
# Training cost: 0.6
# Training accuracy: 0.7
# Valid cost: 0.632
# Valid_UA: 0.5
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00426
# Training cost: 0.665
# Training accuracy: 0.65
# Valid cost: 0.627
# Valid_UA: 0.4631
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[ 92  58]
#  [101  46]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00431
# Training cost: 0.655
# Training accuracy: 0.575
# Valid cost: 0.617
# Valid_UA: 0.5359
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[73 77]
#  [61 86]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00436
# Training cost: 0.614
# Training accuracy: 0.6
# Valid cost: 0.615
# Valid_UA: 0.5
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00441
# Training cost: 0.579
# Training accuracy: 0.7
# Valid cost: 0.612
# Valid_UA: 0.4841
# Best valid_UA: 0.6378
# Valid Confusion Matrix:["cc","cd"]
# [[133  17]
#  [135  12]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 74  76]
#  [ 32 115]]
# *****************************************************************
# *****************************************************************
# Epoch: 00446
# Training cost: 0.544
# Training accuracy: 0.675
# Valid cost: 0.61
# Valid_UA: 0.6739
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00451
# Training cost: 0.642
# Training accuracy: 0.725
# Valid cost: 0.619
# Valid_UA: 0.5035
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[149   1]
#  [145   2]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00456
# Training cost: 0.545
# Training accuracy: 0.675
# Valid cost: 0.595
# Valid_UA: 0.5068
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [145   2]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00461
# Training cost: 0.601
# Training accuracy: 0.65
# Valid cost: 0.601
# Valid_UA: 0.5
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00466
# Training cost: 0.57
# Training accuracy: 0.65
# Valid cost: 0.6
# Valid_UA: 0.5312
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[92 58]
#  [81 66]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00471
# Training cost: 0.647
# Training accuracy: 0.675
# Valid cost: 0.622
# Valid_UA: 0.5071
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[146   4]
#  [141   6]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00476
# Training cost: 0.673
# Training accuracy: 0.5
# Valid cost: 0.604
# Valid_UA: 0.4872
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[88 62]
#  [90 57]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00481
# Training cost: 0.625
# Training accuracy: 0.65
# Valid cost: 0.632
# Valid_UA: 0.4744
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[127  23]
#  [132  15]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00486
# Training cost: 0.714
# Training accuracy: 0.55
# Valid cost: 0.64
# Valid_UA: 0.4825
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[107  43]
#  [110  37]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00491
# Training cost: 0.666
# Training accuracy: 0.625
# Valid cost: 0.622
# Valid_UA: 0.4952
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[120  30]
#  [119  28]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00496
# Training cost: 0.622
# Training accuracy: 0.55
# Valid cost: 0.607
# Valid_UA: 0.5049
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[128  22]
#  [124  23]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00501
# Training cost: 0.553
# Training accuracy: 0.675
# Valid cost: 0.604
# Valid_UA: 0.6703
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[ 97  53]
#  [ 45 102]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00506
# Training cost: 0.584
# Training accuracy: 0.625
# Valid cost: 0.603
# Valid_UA: 0.6413
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[ 73  77]
#  [ 30 117]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00511
# Training cost: 0.587
# Training accuracy: 0.775
# Valid cost: 0.61
# Valid_UA: 0.5
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# *****************************************************************
# Epoch: 00516
# Training cost: 0.53
# Training accuracy: 0.775
# Valid cost: 0.589
# Valid_UA: 0.5
# Best valid_UA: 0.6739
# Valid Confusion Matrix:["cc","cd"]
# [[150   0]
#  [147   0]]
# Best Valid Confusion Matrix:["cc","cd"]
# [[ 93  57]
#  [ 40 107]]
# *****************************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12500/4236886422.py in <module>
#      78                     if(v_end < valid_size):
#      79                         v_end = valid_size
# ---> 80                 loss, y_pred_valid[v_begin:v_end,:] = sess.run([cross_entropy,Ylogits],feed_dict = {X:valid_data[v_begin:v_end],Y:valid_label[v_begin:v_end],is_training:False, keep_prob:1})
#      81                 cost_valid = cost_valid + np.sum(loss)
#      82             cost_valid = cost_valid/valid_size
#
# ~\anaconda3\envs\tf-btp\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     965
#     966     try:
# --> 967       result = self._run(None, fetches, feed_dict, options_ptr,
#     968                          run_metadata_ptr)
#     969       if run_metadata:
#
# ~\anaconda3\envs\tf-btp\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1188     # or if the call is a partial run that specifies feeds.
#    1189     if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1190       results = self._do_run(handle, final_targets, final_fetches,
#    1191                              feed_dict_tensor, options, run_metadata)
#    1192     else:
#
# ~\anaconda3\envs\tf-btp\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1368
#    1369     if handle is None:
# -> 1370       return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1371                            run_metadata)
#    1372     else:
#
# ~\anaconda3\envs\tf-btp\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1375   def _do_call(self, fn, *args):
#    1376     try:
# -> 1377       return fn(*args)
#    1378     except errors.OpError as e:
#    1379       message = compat.as_text(e.message)
#
# ~\anaconda3\envs\tf-btp\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1358       # Ensure any changes to the graph are reflected in the runtime.
#    1359       self._extend_graph()
# -> 1360       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1361                                       target_list, run_metadata)
#    1362
#
# ~\anaconda3\envs\tf-btp\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1451   def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1452                           run_metadata):
# -> 1453     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1454                                             fetch_list, target_list,
#    1455                                             run_metadata)
#
# KeyboardInterrupt:

# %%
type(pernums_valid)

# %%
pernums_valid[0][0]

# %%
y_pred_valid[index:index+ pernums_valid[s][0],:]

# %%
y_pred_valid[0:1:]

# %%
s

# %%
pernums_valid[0][0]
