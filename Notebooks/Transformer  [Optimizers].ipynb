# %%
# importing the libraries
import numpy as np

# for evaluating the model
from sklearn.metrics import accuracy_score
from tqdm import tqdm

# PyTorch libraries and modules
import torch
from torch.autograd import Variable
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD

import pickle
def load_data(in_dir):
    f = open(in_dir,'rb')
    train_data,train_label,valid_data,valid_label = pickle.load(f)
    return train_data,train_label,valid_data,valid_label

# data_path = 'adress_512.pkl'
data_path = 'adress_transformer.pkl'
checkpoint = 'checkpoint/'

train_data,train_label,valid_data,valid_label = load_data(data_path)

# converting training images into torch format
train_x = train_data
train_x  = torch.from_numpy(train_x)

# converting the target into torch format
train_y = train_label
train_y = train_y.reshape(train_y.shape[0]).astype(float);
train_y = torch.from_numpy(train_y)


# shape of training data
# train_x.shape, train_y.shape
from torch.utils.data import TensorDataset, DataLoader

# my_x = [np.array([[1.0,2],[3,4]]),np.array([[5.,6],[7,8]])] # a list of numpy arrays
# my_y = [np.array([4.]), np.array([2.])] # another list of numpy arrays (targets)

# tensor_x = torch.Tensor(my_x) # transform to torch tensor
# tensor_y = torch.Tensor(my_y)

CTX = torch.device('cuda')

train_dataset = TensorDataset(train_x.to(CTX),train_y.to(CTX)) # create your datset

 # create your dataloader

# %%
# converting training images into torch format
val_x = valid_data
val_x  = torch.from_numpy(val_x)

# converting the target into torch format
val_y = valid_label
val_y = val_y.reshape(val_y.shape[0]).astype(float);
val_y = torch.from_numpy(val_y)
# shape of training data

val_dataset = TensorDataset(val_x,val_y) # create your datset

# %%
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split

batch_size = 64
# val_size = 297
# train_size = train_x.size(0) - val_size 

# train_data,val_data = random_split(dataset,[train_size,val_size])
# print(f"Length of Train Data : {len(train_data)}")
# print(f"Length of Validation Data : {len(val_data)}")

#output
#Length of Train Data : 2379
#Length of Validation Data : 297

#load the train and validation into batches.
train_dl = DataLoader(train_dataset,batch_size, shuffle = True, num_workers = 0)
val_dl = DataLoader(val_dataset, batch_size*2, num_workers = 0)

# %%
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import confusion_matrix as confusion
from sklearn.metrics import confusion_matrix as confusion
from sklearn.metrics import recall_score as recall
class ImageClassificationBase(nn.Module):
    
    def training_step(self, batch):
        images, labels = batch 
        out, _softmax= self(images.to(CTX))                  # Generate predictions
        loss = F.cross_entropy(out, labels.to(torch.int64).cuda()) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out, _softmax = self(images.to(CTX))                    # Generate predictions
        loss = F.cross_entropy(out, labels.to(torch.int64).cuda())   # Calculate loss
        acc = accuracy(_softmax, labels.to(torch.int64).cuda())           # Calculate accuracy
        
        valid_conf = confusion(np.argmax(_softmax.cpu(),1),labels.cpu())
#         valid_conf = 8008
#         print(np.argmax(out.cpu(),1))
#         print(labels.cpu())
        print ('Valid Confusion Matrix:["cc","cd"]')
        print(valid_conf)
        print ('Recall')
        print(recall(np.argmax(_softmax.cpu(),1),labels.cpu(),average='macro'))
        return {'val_loss': loss.detach(), 'val_acc': acc }
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.8f}".format(
            epoch, result['train_loss'], result['val_loss'], result['val_acc']))
        
#         print (result['valid_conf'])

# %%
#change nn.sequential to take dict to make more readable 

class parallel_all_you_want(ImageClassificationBase):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__() 
        
        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer 
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        
        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=4, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4, 
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )
        
        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)
        
        ############### 1ST PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock1 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )

        ################# FINAL LINEAR BLOCK ####################
        # Linear softmax layer to take final concatenated embedding tensor 
        #    from parallel 2D convolutional and transformer blocks, output 8 logits 
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array 
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2+40 == 1064 input features --> 8 output emotions 
        self.fc1_linear = nn.Linear(512*2+40,num_emotions) 
        
        ### Softmax layer for the 8 output logits from final FC linear layer 
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding
        
    # define one complete parallel fwd pass of input feature tensor thru 2*conv+1*transformer blocks
    def forward(self,x):
        
        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1) 
        
        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1) 
        
         
        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)
        
        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1) 
        
        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)
        
        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        
        ############# concatenate freq embeddings from convolutional and transformer blocks ######
        # concatenate embedding tensors output by parallel 2*conv and 1*transformer blocks
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)  

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)  
        
        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)
        
        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %%
# defining the model
model = parallel_all_you_want(num_emotions = 2)
# defining the optimizer
optimizer = Adam(model.parameters(), lr=0.07)
# defining the loss function

criterion = CrossEntropyLoss()
# checking if GPU is available
if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()
    
print(model)
# Out:
# parallel_all_you_want(
#   (transformer_maxpool): MaxPool2d(kernel_size=[1, 4], stride=[1, 4], padding=0, dilation=1, ceil_mode=False)
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=40, out_features=40, bias=True)
#         )
#         (linear1): Linear(in_features=40, out_features=512, bias=True)
#         (dropout): Dropout(p=0.4, inplace=False)
#         (linear2): Linear(in_features=512, out_features=40, bias=True)
#         (norm1): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.4, inplace=False)
#         (dropout2): Dropout(p=0.4, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=40, out_features=40, bias=True)
#         )
#         (linear1): Linear(in_features=40, out_features=512, bias=True)
#         (dropout): Dropout(p=0.4, inplace=False)
#         (linear2): Linear(in_features=512, out_features=40, bias=True)
#         (norm1): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.4, inplace=False)
#         (dropout2): Dropout(p=0.4, inplace=False)
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=40, out_features=40, bias=True)
#         )
#         (linear1): Linear(in_features=40, out_features=512, bias=True)
#         (dropout): Dropout(p=0.4, inplace=False)
#         (linear2): Linear(in_features=512, out_features=40, bias=True)
#         (norm1): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.4, inplace=False)
#         (dropout2): Dropout(p=0.4, inplace=False)
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=40, out_features=40, bias=True)
#         )
#         (linear1): Linear(in_features=40, out_features=512, bias=True)
#         (dropout): Dropout(p=0.4, inplace=False)
#         (linear2): Linear(in_features=512, out_features=40, bias=True)
#         (norm1): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((40,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.4, inplace=False)
#         (dropout2): Dropout(p=0.4, inplace=False)
#       )
#     )
#   )
#   (conv2Dblock1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.3, inplace=False)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (9): Dropout(p=0.3, inplace=False)
#     (10): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (14): Dropout(p=0.3, inplace=False)
#   )
#   (conv2Dblock2): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.3, inplace=False)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (9): Dropout(p=0.3, inplace=False)
#     (10): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (14): Dropout(p=0.3, inplace=False)
#   )
#   (fc1_linear): Linear(in_features=1064, out_features=2, bias=True)
#   (softmax_out): Softmax(dim=1)
# )

# %%
# !pip install torch-summary
from torchsummary import summary
# summary(model, (1, 40, 282))

# %%
# input=torch.randn(50,256,7,7)
# bam = BAMBlock(channel=256,reduction=16,dia_val=2)
# output=bam(input)
# print(output.shape)

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

  
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

  
def fit(epochs, lr, model, train_loader, val_loader, opt_func = torch.optim.SGD):
    
    history = []
    optimizer =  torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)
    for epoch in range(epochs):
        
        model.train()
        train_losses = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    
    return history

# %%
# CTX = torch.device('cuda')
# train_dl.to(CTX)  #train_dataset.train_data is a Tensor(input data)
# # train_dl.train_labels.to(CTX)
# # val_dl.train_data.to(CTX)  #train_dataset.train_data is a Tensor(input data)
# # val_dl.train_labels.to(CTX)
num_epochs = 24
opt_func = torch.optim.Adam
opt_func = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)
lr=0.01
#fitting the model on training data and record the result after each epoch
history = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
# Out:
# Valid Confusion Matrix:["cc","cd"]
# [[42 32]
#  [15 39]]
# Recall
# 0.6448948948948949
# Valid Confusion Matrix:["cc","cd"]
# [[0 3]
#  [3 2]]
# Recall
# 0.2
# Epoch [0], train_loss: 2.1780, val_loss: 0.8394, val_acc: 0.44140625
# Valid Confusion Matrix:["cc","cd"]
# [[13 13]
#  [44 58]]
# Recall
# 0.5343137254901961
# Valid Confusion Matrix:["cc","cd"]
# [[1 1]
#  [2 4]]
# Recall
# 0.5833333333333333
# Epoch [1], train_loss: 1.2557, val_loss: 0.6866, val_acc: 0.58984375
# Valid Confusion Matrix:["cc","cd"]
# [[ 0  0]
#  [57 71]]
# Recall
# 0.27734375
# Valid Confusion Matrix:["cc","cd"]
# [[0 0]
#  [3 5]]
# Recall
# 0.3125
# Epoch [2], train_loss: 1.0718, val_loss: 0.7633, val_acc: 0.58984375
# C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Valid Confusion Matrix:["cc","cd"]
# [[ 0  0]
#  [57 71]]
# Recall
# 0.27734375
# Valid Confusion Matrix:["cc","cd"]
# [[0 0]
#  [3 5]]
# Recall
# 0.3125
# Epoch [3], train_loss: 1.1140, val_loss: 0.6669, val_acc: 0.58984375
# C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Valid Confusion Matrix:["cc","cd"]
# [[ 0  0]
#  [57 71]]
# Recall
# 0.27734375
# Valid Confusion Matrix:["cc","cd"]
# [[0 0]
#  [3 5]]
# Recall
# 0.3125
# Epoch [4], train_loss: 1.0852, val_loss: 0.6956, val_acc: 0.58984375
# C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Valid Confusion Matrix:["cc","cd"]
# [[43 48]
#  [14 23]]
# Recall
# 0.5470745470745471
# Valid Confusion Matrix:["cc","cd"]
# [[2 3]
#  [1 2]]
# Recall
# 0.5333333333333333
# Epoch [5], train_loss: 0.8854, val_loss: 0.8289, val_acc: 0.50781250
# Valid Confusion Matrix:["cc","cd"]
# [[ 4  0]
#  [53 71]]
# Recall
# 0.7862903225806452
# Valid Confusion Matrix:["cc","cd"]
# [[0 0]
#  [3 5]]
# Recall
# 0.3125
# Epoch [6], train_loss: 1.0631, val_loss: 0.7141, val_acc: 0.60546875
# C:\Users\Asus\anaconda3\envs\tf-btp\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Valid Confusion Matrix:["cc","cd"]
# [[ 7  0]
#  [50 71]]
# Recall
# 0.7933884297520661
# Valid Confusion Matrix:["cc","cd"]
# [[1 0]
#  [2 5]]
# Recall
# 0.8571428571428572
# Epoch [7], train_loss: 1.3004, val_loss: 0.6618, val_acc: 0.67968750
# Valid Confusion Matrix:["cc","cd"]
# [[15  8]
#  [42 63]]
# Recall
# 0.6260869565217391
# Valid Confusion Matrix:["cc","cd"]
# [[1 1]
#  [2 4]]
# Recall
# 0.5833333333333333
# Epoch [8], train_loss: 0.8289, val_loss: 0.6296, val_acc: 0.61718750
# Valid Confusion Matrix:["cc","cd"]
# [[25 11]
#  [32 60]]
# Recall
# 0.6733091787439613
# Valid Confusion Matrix:["cc","cd"]
# [[1 1]
#  [2 4]]
# Recall
# 0.5833333333333333
# Epoch [9], train_loss: 0.8873, val_loss: 0.6599, val_acc: 0.64453125
# Valid Confusion Matrix:["cc","cd"]
# [[27 12]
#  [30 59]]
# Recall
# 0.6776145203111494
# Valid Confusion Matrix:["cc","cd"]
# [[1 1]
#  [2 4]]
# Recall
# 0.5833333333333333
# Epoch [10], train_loss: 0.7849, val_loss: 0.6341, val_acc: 0.64843750
# Valid Confusion Matrix:["cc","cd"]
# [[24  8]
#  [33 63]]
# Recall
# 0.703125
# Valid Confusion Matrix:["cc","cd"]
# [[1 1]
#  [2 4]]
# Recall
# 0.5833333333333333
# Epoch [11], train_loss: 0.6953, val_loss: 0.6308, val_acc: 0.65234375
# Valid Confusion Matrix:["cc","cd"]
# [[41 24]
#  [16 47]]
# Recall
# 0.6884004884004884
# Valid Confusion Matrix:["cc","cd"]
# [[2 3]
#  [1 2]]
# Recall
# 0.5333333333333333
# Epoch [12], train_loss: 0.7410, val_loss: 0.7311, val_acc: 0.59375000
# Valid Confusion Matrix:["cc","cd"]
# [[37 16]
#  [20 55]]
# Recall
# 0.7157232704402515
# Valid Confusion Matrix:["cc","cd"]
# [[1 2]
#  [2 3]]
# Recall
# 0.4666666666666667
# Epoch [13], train_loss: 0.8186, val_loss: 0.7349, val_acc: 0.60937500
# Valid Confusion Matrix:["cc","cd"]
# [[37 17]
#  [20 54]]
# Recall
# 0.7074574574574575
# Valid Confusion Matrix:["cc","cd"]
# [[3 2]
#  [0 3]]
# Recall
# 0.8
# Epoch [14], train_loss: 0.7060, val_loss: 0.5922, val_acc: 0.73046875
# Valid Confusion Matrix:["cc","cd"]
# [[38 14]
#  [19 57]]
# Recall
# 0.7403846153846154
# Valid Confusion Matrix:["cc","cd"]
# [[2 2]
#  [1 3]]
# Recall
# 0.625
# Epoch [15], train_loss: 0.7438, val_loss: 0.5669, val_acc: 0.68359375
# Valid Confusion Matrix:["cc","cd"]
# [[38 16]
#  [19 55]]
# Recall
# 0.7234734734734735
# Valid Confusion Matrix:["cc","cd"]
# [[2 2]
#  [1 3]]
# Recall
# 0.625
# Epoch [16], train_loss: 0.6673, val_loss: 0.5229, val_acc: 0.67578125
# Valid Confusion Matrix:["cc","cd"]
# [[41 20]
#  [16 51]]
# Recall
# 0.7166625886958649
# Valid Confusion Matrix:["cc","cd"]
# [[3 2]
#  [0 3]]
# Recall
# 0.8
# Epoch [17], train_loss: 0.6240, val_loss: 0.5633, val_acc: 0.73437500
# Valid Confusion Matrix:["cc","cd"]
# [[29 10]
#  [28 61]]
# Recall
# 0.714491501008355
# Valid Confusion Matrix:["cc","cd"]
# [[2 1]
#  [1 4]]
# Recall
# 0.7333333333333334
# Epoch [18], train_loss: 0.6270, val_loss: 0.4702, val_acc: 0.72656250
# Valid Confusion Matrix:["cc","cd"]
# [[44 25]
#  [13 46]]
# Recall
# 0.7086710881847211
# Valid Confusion Matrix:["cc","cd"]
# [[3 2]
#  [0 3]]
# Recall
# 0.8
# Epoch [19], train_loss: 0.6050, val_loss: 0.4787, val_acc: 0.72656250
# Valid Confusion Matrix:["cc","cd"]
# [[47 16]
#  [10 55]]
# Recall
# 0.7960927960927962
# Valid Confusion Matrix:["cc","cd"]
# [[2 2]
#  [1 3]]
# Recall
# 0.625
# Epoch [20], train_loss: 0.6705, val_loss: 0.5593, val_acc: 0.71093750
# Valid Confusion Matrix:["cc","cd"]
# [[29 12]
#  [28 59]]
# Recall
# 0.6927389963554808
# Valid Confusion Matrix:["cc","cd"]
# [[2 2]
#  [1 3]]
# Recall
# 0.625
# Epoch [21], train_loss: 0.6238, val_loss: 0.6000, val_acc: 0.65625000
# Valid Confusion Matrix:["cc","cd"]
# [[47 17]
#  [10 54]]
# Recall
# 0.7890625
# Valid Confusion Matrix:["cc","cd"]
# [[2 2]
#  [1 3]]
# Recall
# 0.625
# Epoch [22], train_loss: 0.6207, val_loss: 0.5547, val_acc: 0.70703125
# Valid Confusion Matrix:["cc","cd"]
# [[38  9]
#  [19 62]]
# Recall
# 0.7869713685316522
# Valid Confusion Matrix:["cc","cd"]
# [[2 0]
#  [1 5]]
# Recall
# 0.9166666666666667
# Epoch [23], train_loss: 0.5919, val_loss: 0.4443, val_acc: 0.82812500

# %%
import matplotlib.pyplot as plt

def plot_accuracies(history):
    """ Plot the history of accuracies"""
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');
    

plot_accuracies(history)

def plot_losses(history):
    """ Plot the losses in each epoch"""
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

plot_losses(history)

# %%
max([x['val_acc'] for x in history])
# Out:
# 0.828125

# %%
# define loss function; CrossEntropyLoss() fairly standard for multiclass problems 
def criterion(predictions, targets): 
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# define function to create a single step of the training phase
def make_train_step(model, criterion, optimizer):
    
    # define the training step of the training phase
    def train_step(X,Y):
        
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y) 
        
        # compute gradients for the optimizer to use 
        loss.backward()
        
        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()
        
        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad() 
        
        return loss.item(), accuracy*100
    return train_step

def make_validate_fnc(model,criterion):
    def validate(X,Y):
        
        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase: 
        with torch.no_grad(): 
            
            # set model to validation phase i.e. turn off dropout and batchnorm layers 
            model.eval()
      
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            
            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)
            
        return loss.item(), accuracy*100, predictions
    return validate

def make_save_checkpoint(): 
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = train_x.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_all_you_want(num_emotions=2).to(device) 
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function 
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []

# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):
        
        # set model to train phase
        model.train()         
        
        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size) 
        
        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:] 
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate 
        epoch_acc = 0 
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)
        
        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):
            
            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch 
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size) 
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start 
            
            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:] 
            # get training minibatch labels 
            Y = Y_train[batch_start:batch_end] 

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float() 
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor) 
            
            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            
            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')
        
        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
                  
        # Save checkpoint of the model
        checkpoint_filename = 'checkpoint/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)
        
        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
# Out:
# cuda selected
# Number of trainable params:  242098

# %%
# choose number of epochs higher than reasonable so we can manually stop training 
num_epochs = 500

# train it!
train(optimizer, model, num_epochs, train_x, train_y, val_x, val_y)
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_15788/2864264818.py:69: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_tensor = torch.tensor(X, device=device).float()
# C:\Users\Asus\AppData\Local\Temp/ipykernel_15788/2864264818.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
# Epoch 0: iteration 79/80
# C:\Users\Asus\AppData\Local\Temp/ipykernel_15788/2864264818.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_valid_tensor = torch.tensor(X_valid,device=device).float()
# C:\Users\Asus\AppData\Local\Temp/ipykernel_15788/2864264818.py:84: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
# Epoch 0 --- loss:1.762, Epoch accuracy:55.08%, Validation loss:0.815, Validation accuracy:53.68%
# Epoch 1: iteration 79/80
# Epoch 1 --- loss:1.356, Epoch accuracy:56.83%, Validation loss:1.125, Validation accuracy:50.74%
# Epoch 2: iteration 79/80
# Epoch 2 --- loss:1.150, Epoch accuracy:58.19%, Validation loss:0.695, Validation accuracy:66.18%
# Epoch 3: iteration 79/80
# Epoch 3 --- loss:1.224, Epoch accuracy:60.37%, Validation loss:1.078, Validation accuracy:45.59%
# Epoch 4: iteration 79/80
# Epoch 4 --- loss:0.946, Epoch accuracy:62.59%, Validation loss:0.943, Validation accuracy:67.65%
# Epoch 5: iteration 79/80
# Epoch 5 --- loss:0.906, Epoch accuracy:65.67%, Validation loss:0.629, Validation accuracy:69.85%
# Epoch 6: iteration 79/80
# Epoch 6 --- loss:0.899, Epoch accuracy:63.02%, Validation loss:0.567, Validation accuracy:69.12%
# Epoch 7: iteration 79/80
# Epoch 7 --- loss:0.850, Epoch accuracy:66.13%, Validation loss:0.584, Validation accuracy:74.26%
# Epoch 8: iteration 79/80
# Epoch 8 --- loss:0.722, Epoch accuracy:68.31%, Validation loss:0.570, Validation accuracy:69.85%
# Epoch 9: iteration 79/80
# Epoch 9 --- loss:0.637, Epoch accuracy:70.92%, Validation loss:0.564, Validation accuracy:72.06%
# Epoch 10: iteration 79/80
# Epoch 10 --- loss:0.661, Epoch accuracy:70.14%, Validation loss:0.622, Validation accuracy:70.59%
# Epoch 11: iteration 79/80
# Epoch 11 --- loss:0.621, Epoch accuracy:72.40%, Validation loss:0.642, Validation accuracy:74.26%
# Epoch 12: iteration 79/80
# Epoch 12 --- loss:0.602, Epoch accuracy:73.69%, Validation loss:0.568, Validation accuracy:77.21%
# Epoch 13: iteration 79/80
# Epoch 13 --- loss:0.532, Epoch accuracy:75.91%, Validation loss:0.463, Validation accuracy:79.41%
# Epoch 14: iteration 79/80
# Epoch 14 --- loss:0.560, Epoch accuracy:76.14%, Validation loss:0.796, Validation accuracy:65.44%
# Epoch 15: iteration 79/80
# Epoch 15 --- loss:0.527, Epoch accuracy:76.10%, Validation loss:0.410, Validation accuracy:81.62%
# Epoch 16: iteration 79/80
# Epoch 16 --- loss:0.475, Epoch accuracy:78.98%, Validation loss:0.419, Validation accuracy:80.15%
# Epoch 17: iteration 79/80
# Epoch 17 --- loss:0.472, Epoch accuracy:79.99%, Validation loss:0.454, Validation accuracy:80.88%
# Epoch 18: iteration 79/80
# Epoch 18 --- loss:0.483, Epoch accuracy:78.94%, Validation loss:0.451, Validation accuracy:79.41%
# Epoch 19: iteration 79/80
# Epoch 19 --- loss:0.426, Epoch accuracy:81.47%, Validation loss:0.466, Validation accuracy:79.41%
# Epoch 20: iteration 79/80
# Epoch 20 --- loss:0.426, Epoch accuracy:81.24%, Validation loss:0.392, Validation accuracy:83.09%
# Epoch 21: iteration 79/80
# Epoch 21 --- loss:0.414, Epoch accuracy:82.52%, Validation loss:0.354, Validation accuracy:84.56%
# Epoch 22: iteration 79/80
# Epoch 22 --- loss:0.375, Epoch accuracy:84.35%, Validation loss:0.380, Validation accuracy:82.35%
# Epoch 23: iteration 79/80
# Epoch 23 --- loss:0.422, Epoch accuracy:81.94%, Validation loss:0.364, Validation accuracy:83.09%
# Epoch 24: iteration 79/80
# Epoch 24 --- loss:0.363, Epoch accuracy:84.24%, Validation loss:0.297, Validation accuracy:86.76%
# Epoch 25: iteration 79/80
# Epoch 25 --- loss:0.347, Epoch accuracy:85.09%, Validation loss:0.449, Validation accuracy:83.09%
# Epoch 26: iteration 79/80
# Epoch 26 --- loss:0.370, Epoch accuracy:83.69%, Validation loss:0.270, Validation accuracy:88.24%
# Epoch 27: iteration 79/80
# Epoch 27 --- loss:0.328, Epoch accuracy:85.52%, Validation loss:0.286, Validation accuracy:86.76%
# Epoch 28: iteration 79/80
# Epoch 28 --- loss:0.340, Epoch accuracy:84.94%, Validation loss:0.213, Validation accuracy:90.44%
# Epoch 29: iteration 79/80
# Epoch 29 --- loss:0.327, Epoch accuracy:85.79%, Validation loss:0.444, Validation accuracy:83.09%
# Epoch 30: iteration 79/80
# Epoch 30 --- loss:0.316, Epoch accuracy:86.30%, Validation loss:0.295, Validation accuracy:87.50%
# Epoch 31: iteration 79/80
# Epoch 31 --- loss:0.313, Epoch accuracy:86.57%, Validation loss:0.240, Validation accuracy:86.03%
# Epoch 32: iteration 79/80
# Epoch 32 --- loss:0.307, Epoch accuracy:87.58%, Validation loss:0.307, Validation accuracy:85.29%
# Epoch 33: iteration 79/80
# Epoch 33 --- loss:0.279, Epoch accuracy:88.75%, Validation loss:0.411, Validation accuracy:85.29%
# Epoch 34: iteration 79/80
# Epoch 34 --- loss:0.283, Epoch accuracy:88.09%, Validation loss:0.420, Validation accuracy:85.29%
# Epoch 35: iteration 79/80
# Epoch 35 --- loss:0.288, Epoch accuracy:88.13%, Validation loss:0.247, Validation accuracy:89.71%
# Epoch 36: iteration 79/80
# Epoch 36 --- loss:0.248, Epoch accuracy:89.72%, Validation loss:0.308, Validation accuracy:88.24%
# Epoch 37: iteration 79/80
# Epoch 37 --- loss:0.253, Epoch accuracy:88.87%, Validation loss:0.275, Validation accuracy:88.97%
# Epoch 38: iteration 79/80
# Epoch 38 --- loss:0.230, Epoch accuracy:90.00%, Validation loss:0.297, Validation accuracy:87.50%
# Epoch 39: iteration 79/80
# Epoch 39 --- loss:0.259, Epoch accuracy:88.71%, Validation loss:0.227, Validation accuracy:93.38%
# Epoch 40: iteration 79/80
# Epoch 40 --- loss:0.251, Epoch accuracy:89.45%, Validation loss:0.211, Validation accuracy:90.44%
# Epoch 41: iteration 79/80
# Epoch 41 --- loss:0.235, Epoch accuracy:90.27%, Validation loss:0.356, Validation accuracy:88.24%
# Epoch 42: iteration 79/80
# Epoch 42 --- loss:0.228, Epoch accuracy:90.23%, Validation loss:0.517, Validation accuracy:82.35%
# Epoch 43: iteration 79/80
# Epoch 43 --- loss:0.213, Epoch accuracy:90.50%, Validation loss:0.291, Validation accuracy:88.97%
# Epoch 44: iteration 79/80
# Epoch 44 --- loss:0.219, Epoch accuracy:90.50%, Validation loss:0.206, Validation accuracy:91.18%
# Epoch 45: iteration 79/80
# Epoch 45 --- loss:0.195, Epoch accuracy:91.59%, Validation loss:0.369, Validation accuracy:86.76%
# Epoch 46: iteration 79/80
# Epoch 46 --- loss:0.210, Epoch accuracy:91.09%, Validation loss:0.209, Validation accuracy:90.44%
# Epoch 47: iteration 79/80
# Epoch 47 --- loss:0.180, Epoch accuracy:92.95%, Validation loss:0.385, Validation accuracy:90.44%
# Epoch 48: iteration 79/80
# Epoch 48 --- loss:0.190, Epoch accuracy:92.10%, Validation loss:0.320, Validation accuracy:88.97%
# Epoch 49: iteration 79/80
# Epoch 49 --- loss:0.191, Epoch accuracy:91.98%, Validation loss:0.226, Validation accuracy:91.91%
# Epoch 50: iteration 79/80
# Epoch 50 --- loss:0.207, Epoch accuracy:91.28%, Validation loss:0.203, Validation accuracy:90.44%
# Epoch 51: iteration 79/80
# Epoch 51 --- loss:0.169, Epoch accuracy:92.37%, Validation loss:0.245, Validation accuracy:88.97%
# Epoch 52: iteration 79/80
# Epoch 52 --- loss:0.208, Epoch accuracy:91.83%, Validation loss:0.342, Validation accuracy:89.71%
# Epoch 53: iteration 79/80
# Epoch 53 --- loss:0.169, Epoch accuracy:93.11%, Validation loss:0.271, Validation accuracy:91.91%
# Epoch 54: iteration 79/80
# Epoch 54 --- loss:0.166, Epoch accuracy:93.11%, Validation loss:0.353, Validation accuracy:88.97%
# Epoch 55: iteration 79/80
# Epoch 55 --- loss:0.190, Epoch accuracy:92.29%, Validation loss:0.295, Validation accuracy:85.29%
# Epoch 56: iteration 79/80
# Epoch 56 --- loss:0.214, Epoch accuracy:90.85%, Validation loss:0.145, Validation accuracy:95.59%
# Epoch 57: iteration 79/80
# Epoch 57 --- loss:0.188, Epoch accuracy:91.90%, Validation loss:0.171, Validation accuracy:93.38%
# Epoch 58: iteration 79/80
# Epoch 58 --- loss:0.176, Epoch accuracy:92.99%, Validation loss:0.153, Validation accuracy:93.38%
# Epoch 59: iteration 79/80
# Epoch 59 --- loss:0.176, Epoch accuracy:92.92%, Validation loss:0.326, Validation accuracy:88.97%
# Epoch 60: iteration 79/80
# Epoch 60 --- loss:0.170, Epoch accuracy:92.68%, Validation loss:0.356, Validation accuracy:87.50%
# Epoch 61: iteration 79/80
# Epoch 61 --- loss:0.194, Epoch accuracy:92.02%, Validation loss:0.463, Validation accuracy:84.56%
# Epoch 62: iteration 79/80
# Epoch 62 --- loss:0.163, Epoch accuracy:93.15%, Validation loss:0.196, Validation accuracy:90.44%
# Epoch 63: iteration 79/80
# Epoch 63 --- loss:0.174, Epoch accuracy:92.92%, Validation loss:0.366, Validation accuracy:86.76%
# Epoch 64: iteration 79/80
# Epoch 64 --- loss:0.154, Epoch accuracy:93.27%, Validation loss:0.174, Validation accuracy:92.65%
# Epoch 65: iteration 79/80
# Epoch 65 --- loss:0.130, Epoch accuracy:94.55%, Validation loss:0.306, Validation accuracy:91.18%
# Epoch 66: iteration 79/80
# Epoch 66 --- loss:0.133, Epoch accuracy:94.36%, Validation loss:0.353, Validation accuracy:91.91%
# Epoch 67: iteration 79/80
# Epoch 67 --- loss:0.171, Epoch accuracy:92.72%, Validation loss:0.247, Validation accuracy:93.38%
# Epoch 68: iteration 79/80
# Epoch 68 --- loss:0.123, Epoch accuracy:94.90%, Validation loss:0.217, Validation accuracy:89.71%
# Epoch 69: iteration 79/80
# Epoch 69 --- loss:0.149, Epoch accuracy:93.54%, Validation loss:0.198, Validation accuracy:92.65%
# Epoch 70: iteration 79/80
# Epoch 70 --- loss:0.128, Epoch accuracy:94.51%, Validation loss:0.180, Validation accuracy:94.12%
# Epoch 71: iteration 79/80
# Epoch 71 --- loss:0.114, Epoch accuracy:95.45%, Validation loss:0.143, Validation accuracy:94.12%
# Epoch 72: iteration 79/80
# Epoch 72 --- loss:0.130, Epoch accuracy:94.82%, Validation loss:0.337, Validation accuracy:90.44%
# Epoch 73: iteration 79/80
# Epoch 73 --- loss:0.148, Epoch accuracy:94.01%, Validation loss:0.182, Validation accuracy:94.12%
# Epoch 74: iteration 79/80
# Epoch 74 --- loss:0.118, Epoch accuracy:95.13%, Validation loss:0.341, Validation accuracy:88.97%
# Epoch 75: iteration 79/80
# Epoch 75 --- loss:0.100, Epoch accuracy:95.76%, Validation loss:0.483, Validation accuracy:88.97%
# Epoch 76: iteration 79/80
# Epoch 76 --- loss:0.142, Epoch accuracy:93.69%, Validation loss:0.262, Validation accuracy:91.91%
# Epoch 77: iteration 79/80
# Epoch 77 --- loss:0.112, Epoch accuracy:95.25%, Validation loss:0.278, Validation accuracy:91.91%
# Epoch 78: iteration 79/80
# Epoch 78 --- loss:0.098, Epoch accuracy:95.99%, Validation loss:0.370, Validation accuracy:88.24%
# Epoch 79: iteration 79/80
# Epoch 79 --- loss:0.127, Epoch accuracy:94.32%, Validation loss:0.159, Validation accuracy:95.59%
# Epoch 80: iteration 79/80
# Epoch 80 --- loss:0.087, Epoch accuracy:96.22%, Validation loss:0.152, Validation accuracy:92.65%
# Epoch 81: iteration 79/80
# Epoch 81 --- loss:0.154, Epoch accuracy:93.81%, Validation loss:0.337, Validation accuracy:87.50%
# Epoch 82: iteration 79/80
# Epoch 82 --- loss:0.104, Epoch accuracy:95.60%, Validation loss:0.335, Validation accuracy:89.71%
# Epoch 83: iteration 79/80
# Epoch 83 --- loss:0.116, Epoch accuracy:95.21%, Validation loss:0.195, Validation accuracy:94.12%
# Epoch 84: iteration 79/80
# Epoch 84 --- loss:0.111, Epoch accuracy:95.33%, Validation loss:0.195, Validation accuracy:93.38%
# Epoch 85: iteration 79/80
# Epoch 85 --- loss:0.128, Epoch accuracy:94.63%, Validation loss:0.351, Validation accuracy:87.50%
# Epoch 86: iteration 79/80
# Epoch 86 --- loss:0.096, Epoch accuracy:95.91%, Validation loss:0.207, Validation accuracy:94.85%
# Epoch 87: iteration 79/80
# Epoch 87 --- loss:0.102, Epoch accuracy:95.87%, Validation loss:0.379, Validation accuracy:90.44%
# Epoch 88: iteration 79/80
# Epoch 88 --- loss:0.085, Epoch accuracy:96.61%, Validation loss:0.293, Validation accuracy:89.71%
# Epoch 89: iteration 79/80
# Epoch 89 --- loss:0.109, Epoch accuracy:95.17%, Validation loss:0.148, Validation accuracy:93.38%
# Epoch 90: iteration 79/80
# Epoch 90 --- loss:0.103, Epoch accuracy:95.37%, Validation loss:0.429, Validation accuracy:86.76%
# Epoch 91: iteration 79/80
# Epoch 91 --- loss:0.111, Epoch accuracy:95.60%, Validation loss:0.241, Validation accuracy:93.38%
# Epoch 92: iteration 79/80
# Epoch 92 --- loss:0.104, Epoch accuracy:95.68%, Validation loss:0.162, Validation accuracy:93.38%
# Epoch 93: iteration 79/80
# Epoch 93 --- loss:0.100, Epoch accuracy:95.52%, Validation loss:0.281, Validation accuracy:94.85%
# Epoch 94: iteration 79/80
# Epoch 94 --- loss:0.096, Epoch accuracy:95.87%, Validation loss:0.246, Validation accuracy:91.91%
# Epoch 95: iteration 79/80
# Epoch 95 --- loss:0.100, Epoch accuracy:95.95%, Validation loss:0.202, Validation accuracy:91.18%
# Epoch 96: iteration 79/80
# Epoch 96 --- loss:0.078, Epoch accuracy:96.96%, Validation loss:0.158, Validation accuracy:94.12%
# Epoch 97: iteration 79/80
# Epoch 97 --- loss:0.109, Epoch accuracy:95.37%, Validation loss:0.189, Validation accuracy:96.32%
# Epoch 98: iteration 79/80
# Epoch 98 --- loss:0.083, Epoch accuracy:96.61%, Validation loss:0.297, Validation accuracy:92.65%
# Epoch 99: iteration 79/80
# Epoch 99 --- loss:0.089, Epoch accuracy:95.91%, Validation loss:0.302, Validation accuracy:90.44%
# Epoch 100: iteration 79/80
# Epoch 100 --- loss:0.104, Epoch accuracy:95.33%, Validation loss:0.298, Validation accuracy:88.24%
# Epoch 101: iteration 79/80
# Epoch 101 --- loss:0.111, Epoch accuracy:95.52%, Validation loss:0.324, Validation accuracy:89.71%
# Epoch 102: iteration 79/80
# Epoch 102 --- loss:0.112, Epoch accuracy:95.21%, Validation loss:0.366, Validation accuracy:88.97%
# Epoch 103: iteration 79/80
# Epoch 103 --- loss:0.090, Epoch accuracy:96.19%, Validation loss:0.435, Validation accuracy:90.44%
# Epoch 104: iteration 79/80
# Epoch 104 --- loss:0.103, Epoch accuracy:95.33%, Validation loss:0.222, Validation accuracy:92.65%
# Epoch 105: iteration 79/80
# Epoch 105 --- loss:0.085, Epoch accuracy:96.19%, Validation loss:0.218, Validation accuracy:92.65%
# Epoch 106: iteration 79/80
# Epoch 106 --- loss:0.073, Epoch accuracy:96.69%, Validation loss:0.177, Validation accuracy:95.59%
# Epoch 107: iteration 79/80
# Epoch 107 --- loss:0.120, Epoch accuracy:95.29%, Validation loss:0.172, Validation accuracy:91.91%
# Epoch 108: iteration 79/80
# Epoch 108 --- loss:0.091, Epoch accuracy:96.22%, Validation loss:0.179, Validation accuracy:95.59%
# Epoch 109: iteration 79/80
# Epoch 109 --- loss:0.082, Epoch accuracy:96.61%, Validation loss:0.339, Validation accuracy:91.91%
# Epoch 110: iteration 79/80
# Epoch 110 --- loss:0.089, Epoch accuracy:95.68%, Validation loss:0.208, Validation accuracy:91.18%
# Epoch 111: iteration 79/80
# Epoch 111 --- loss:0.079, Epoch accuracy:96.69%, Validation loss:0.284, Validation accuracy:91.18%
# Epoch 112: iteration 79/80
# Epoch 112 --- loss:0.075, Epoch accuracy:96.54%, Validation loss:0.269, Validation accuracy:92.65%
# Epoch 113: iteration 79/80
# Epoch 113 --- loss:0.089, Epoch accuracy:96.26%, Validation loss:0.361, Validation accuracy:88.97%
# Epoch 114: iteration 79/80
# Epoch 114 --- loss:0.090, Epoch accuracy:96.38%, Validation loss:0.202, Validation accuracy:93.38%
# Epoch 115: iteration 79/80
# Epoch 115 --- loss:0.097, Epoch accuracy:95.80%, Validation loss:0.155, Validation accuracy:93.38%
# Epoch 116: iteration 79/80
# Epoch 116 --- loss:0.103, Epoch accuracy:95.25%, Validation loss:0.278, Validation accuracy:92.65%
# Epoch 117: iteration 79/80
# Epoch 117 --- loss:0.082, Epoch accuracy:96.46%, Validation loss:0.135, Validation accuracy:97.06%
# Epoch 118: iteration 79/80
# Epoch 118 --- loss:0.049, Epoch accuracy:97.82%, Validation loss:0.229, Validation accuracy:91.91%
# Epoch 119: iteration 79/80
# Epoch 119 --- loss:0.113, Epoch accuracy:95.37%, Validation loss:0.193, Validation accuracy:92.65%
# Epoch 120: iteration 79/80
# Epoch 120 --- loss:0.085, Epoch accuracy:96.46%, Validation loss:0.140, Validation accuracy:95.59%
# Epoch 121: iteration 79/80
# Epoch 121 --- loss:0.066, Epoch accuracy:97.16%, Validation loss:0.249, Validation accuracy:93.38%
# Epoch 122: iteration 79/80
# Epoch 122 --- loss:0.095, Epoch accuracy:95.83%, Validation loss:0.293, Validation accuracy:91.18%
# Epoch 123: iteration 79/80
# Epoch 123 --- loss:0.069, Epoch accuracy:96.89%, Validation loss:0.207, Validation accuracy:91.18%
# Epoch 124: iteration 79/80
# Epoch 124 --- loss:0.067, Epoch accuracy:97.04%, Validation loss:0.232, Validation accuracy:92.65%
# Epoch 125: iteration 79/80
# Epoch 125 --- loss:0.070, Epoch accuracy:97.20%, Validation loss:0.581, Validation accuracy:87.50%
# Epoch 126: iteration 79/80
# Epoch 126 --- loss:0.094, Epoch accuracy:95.99%, Validation loss:0.146, Validation accuracy:94.12%
# Epoch 127: iteration 79/80
# Epoch 127 --- loss:0.054, Epoch accuracy:97.63%, Validation loss:0.153, Validation accuracy:94.85%
# Epoch 128: iteration 79/80
# Epoch 128 --- loss:0.088, Epoch accuracy:96.42%, Validation loss:0.308, Validation accuracy:93.38%
# Epoch 129: iteration 79/80
# Epoch 129 --- loss:0.072, Epoch accuracy:97.16%, Validation loss:0.196, Validation accuracy:96.32%
# Epoch 130: iteration 79/80
# Epoch 130 --- loss:0.095, Epoch accuracy:96.15%, Validation loss:0.146, Validation accuracy:94.85%
# Epoch 131: iteration 79/80
# Epoch 131 --- loss:0.052, Epoch accuracy:97.39%, Validation loss:0.377, Validation accuracy:91.18%
# Epoch 132: iteration 79/80
# Epoch 132 --- loss:0.119, Epoch accuracy:95.10%, Validation loss:0.232, Validation accuracy:91.91%
# Epoch 133: iteration 79/80
# Epoch 133 --- loss:0.051, Epoch accuracy:97.82%, Validation loss:0.138, Validation accuracy:94.85%
# Epoch 134: iteration 79/80
# Epoch 134 --- loss:0.063, Epoch accuracy:97.39%, Validation loss:0.192, Validation accuracy:94.12%
# Epoch 135: iteration 79/80
# Epoch 135 --- loss:0.124, Epoch accuracy:95.25%, Validation loss:0.238, Validation accuracy:93.38%
# Epoch 136: iteration 79/80
# Epoch 136 --- loss:0.066, Epoch accuracy:97.24%, Validation loss:0.283, Validation accuracy:91.91%
# Epoch 137: iteration 79/80
# Epoch 137 --- loss:0.071, Epoch accuracy:96.96%, Validation loss:0.264, Validation accuracy:91.91%
# Epoch 138: iteration 79/80
# Epoch 138 --- loss:0.047, Epoch accuracy:97.94%, Validation loss:0.226, Validation accuracy:95.59%
# Epoch 139: iteration 79/80
# Epoch 139 --- loss:0.059, Epoch accuracy:97.39%, Validation loss:0.145, Validation accuracy:94.85%
# Epoch 140: iteration 79/80
# Epoch 140 --- loss:0.047, Epoch accuracy:97.86%, Validation loss:0.358, Validation accuracy:90.44%
# Epoch 141: iteration 79/80
# Epoch 141 --- loss:0.103, Epoch accuracy:95.52%, Validation loss:0.241, Validation accuracy:94.85%
# Epoch 142: iteration 79/80
# Epoch 142 --- loss:0.078, Epoch accuracy:96.54%, Validation loss:0.200, Validation accuracy:94.12%
# Epoch 143: iteration 79/80
# Epoch 143 --- loss:0.052, Epoch accuracy:97.59%, Validation loss:0.559, Validation accuracy:87.50%
# Epoch 144: iteration 79/80
# Epoch 144 --- loss:0.111, Epoch accuracy:95.45%, Validation loss:0.193, Validation accuracy:92.65%
# Epoch 145: iteration 79/80
# Epoch 145 --- loss:0.056, Epoch accuracy:97.63%, Validation loss:0.148, Validation accuracy:94.12%
# Epoch 146: iteration 79/80
# Epoch 146 --- loss:0.072, Epoch accuracy:96.85%, Validation loss:0.244, Validation accuracy:91.18%
# Epoch 147: iteration 79/80
# Epoch 147 --- loss:0.071, Epoch accuracy:96.96%, Validation loss:0.330, Validation accuracy:91.91%
# Epoch 148: iteration 79/80
# Epoch 148 --- loss:0.057, Epoch accuracy:97.74%, Validation loss:0.168, Validation accuracy:94.85%
# Epoch 149: iteration 79/80
# Epoch 149 --- loss:0.054, Epoch accuracy:97.43%, Validation loss:0.572, Validation accuracy:84.56%
# Epoch 150: iteration 79/80
# Epoch 150 --- loss:0.089, Epoch accuracy:96.11%, Validation loss:0.337, Validation accuracy:88.97%
# Epoch 151: iteration 79/80
# Epoch 151 --- loss:0.048, Epoch accuracy:97.98%, Validation loss:0.192, Validation accuracy:93.38%
# Epoch 152: iteration 79/80
# Epoch 152 --- loss:0.060, Epoch accuracy:97.39%, Validation loss:0.137, Validation accuracy:97.79%
# Epoch 153: iteration 79/80
# Epoch 153 --- loss:0.077, Epoch accuracy:96.54%, Validation loss:0.283, Validation accuracy:90.44%
# Epoch 154: iteration 79/80
# Epoch 154 --- loss:0.039, Epoch accuracy:98.13%, Validation loss:0.217, Validation accuracy:92.65%
# Epoch 155: iteration 79/80
# Epoch 155 --- loss:0.076, Epoch accuracy:97.04%, Validation loss:0.170, Validation accuracy:96.32%
# Epoch 156: iteration 79/80
# Epoch 156 --- loss:0.056, Epoch accuracy:97.35%, Validation loss:0.291, Validation accuracy:93.38%
# Epoch 157: iteration 79/80
# Epoch 157 --- loss:0.094, Epoch accuracy:96.26%, Validation loss:0.287, Validation accuracy:92.65%
# Epoch 158: iteration 79/80
# Epoch 158 --- loss:0.047, Epoch accuracy:97.94%, Validation loss:0.172, Validation accuracy:94.12%
# Epoch 159: iteration 79/80
# Epoch 159 --- loss:0.060, Epoch accuracy:97.12%, Validation loss:0.170, Validation accuracy:94.12%
# Epoch 160: iteration 79/80
# Epoch 160 --- loss:0.135, Epoch accuracy:94.71%, Validation loss:0.387, Validation accuracy:91.91%
# Epoch 161: iteration 79/80
# Epoch 161 --- loss:0.059, Epoch accuracy:97.86%, Validation loss:0.181, Validation accuracy:94.12%
# Epoch 162: iteration 79/80
# Epoch 162 --- loss:0.036, Epoch accuracy:98.29%, Validation loss:0.344, Validation accuracy:91.18%
# Epoch 163: iteration 79/80
# Epoch 163 --- loss:0.088, Epoch accuracy:96.42%, Validation loss:0.412, Validation accuracy:90.44%
# Epoch 164: iteration 79/80
# Epoch 164 --- loss:0.054, Epoch accuracy:97.86%, Validation loss:0.183, Validation accuracy:95.59%
# Epoch 165: iteration 79/80
# Epoch 165 --- loss:0.073, Epoch accuracy:96.46%, Validation loss:0.162, Validation accuracy:96.32%
# Epoch 166: iteration 79/80
# Epoch 166 --- loss:0.108, Epoch accuracy:95.48%, Validation loss:0.222, Validation accuracy:93.38%
# Epoch 167: iteration 79/80
# Epoch 167 --- loss:0.058, Epoch accuracy:97.43%, Validation loss:0.133, Validation accuracy:93.38%
# Epoch 168: iteration 79/80
# Epoch 168 --- loss:0.056, Epoch accuracy:97.20%, Validation loss:0.119, Validation accuracy:95.59%
# Epoch 169: iteration 79/80
# Epoch 169 --- loss:0.100, Epoch accuracy:95.72%, Validation loss:0.191, Validation accuracy:96.32%
# Epoch 170: iteration 79/80
# Epoch 170 --- loss:0.062, Epoch accuracy:97.28%, Validation loss:0.150, Validation accuracy:95.59%
# Epoch 171: iteration 79/80
# Epoch 171 --- loss:0.073, Epoch accuracy:96.89%, Validation loss:0.179, Validation accuracy:96.32%
# Epoch 172: iteration 79/80
# Epoch 172 --- loss:0.044, Epoch accuracy:98.17%, Validation loss:0.215, Validation accuracy:94.12%
# Epoch 173: iteration 79/80
# Epoch 173 --- loss:0.043, Epoch accuracy:98.13%, Validation loss:0.268, Validation accuracy:92.65%
# Epoch 174: iteration 79/80
# Epoch 174 --- loss:0.074, Epoch accuracy:96.65%, Validation loss:0.391, Validation accuracy:89.71%
# Epoch 175: iteration 79/80
# Epoch 175 --- loss:0.081, Epoch accuracy:96.65%, Validation loss:0.183, Validation accuracy:94.12%
# Epoch 176: iteration 79/80
# Epoch 176 --- loss:0.031, Epoch accuracy:98.64%, Validation loss:0.139, Validation accuracy:94.85%
# Epoch 177: iteration 79/80
# Epoch 177 --- loss:0.077, Epoch accuracy:96.73%, Validation loss:0.181, Validation accuracy:94.12%
# Epoch 178: iteration 79/80
# Epoch 178 --- loss:0.069, Epoch accuracy:97.20%, Validation loss:0.316, Validation accuracy:92.65%
# Epoch 179: iteration 79/80
# Epoch 179 --- loss:0.062, Epoch accuracy:97.24%, Validation loss:0.206, Validation accuracy:95.59%
# Epoch 180: iteration 79/80
# Epoch 180 --- loss:0.062, Epoch accuracy:97.78%, Validation loss:0.302, Validation accuracy:91.91%
# Epoch 181: iteration 79/80
# Epoch 181 --- loss:0.069, Epoch accuracy:96.54%, Validation loss:0.350, Validation accuracy:90.44%
# Epoch 182: iteration 79/80
# Epoch 182 --- loss:0.073, Epoch accuracy:96.65%, Validation loss:0.253, Validation accuracy:92.65%
# Epoch 183: iteration 79/80
# Epoch 183 --- loss:0.051, Epoch accuracy:97.74%, Validation loss:0.197, Validation accuracy:93.38%
# Epoch 184: iteration 79/80
# Epoch 184 --- loss:0.047, Epoch accuracy:98.17%, Validation loss:0.155, Validation accuracy:94.85%
# Epoch 185: iteration 79/80
# Epoch 185 --- loss:0.057, Epoch accuracy:97.39%, Validation loss:0.231, Validation accuracy:92.65%
# Epoch 186: iteration 79/80
# Epoch 186 --- loss:0.055, Epoch accuracy:97.24%, Validation loss:0.364, Validation accuracy:91.18%
# Epoch 187: iteration 79/80
# Epoch 187 --- loss:0.089, Epoch accuracy:96.22%, Validation loss:0.274, Validation accuracy:93.38%
# Epoch 188: iteration 79/80
# Epoch 188 --- loss:0.069, Epoch accuracy:97.24%, Validation loss:0.286, Validation accuracy:92.65%
# Epoch 189: iteration 79/80
# Epoch 189 --- loss:0.072, Epoch accuracy:96.73%, Validation loss:0.261, Validation accuracy:91.18%
# Epoch 190: iteration 79/80
# Epoch 190 --- loss:0.050, Epoch accuracy:98.13%, Validation loss:0.285, Validation accuracy:92.65%
# Epoch 191: iteration 79/80
# Epoch 191 --- loss:0.044, Epoch accuracy:97.94%, Validation loss:0.237, Validation accuracy:93.38%
# Epoch 192: iteration 79/80
# Epoch 192 --- loss:0.029, Epoch accuracy:98.60%, Validation loss:0.149, Validation accuracy:94.85%
# Epoch 193: iteration 79/80
# Epoch 193 --- loss:0.043, Epoch accuracy:98.17%, Validation loss:0.133, Validation accuracy:94.85%
# Epoch 194: iteration 79/80
# Epoch 194 --- loss:0.047, Epoch accuracy:97.82%, Validation loss:0.334, Validation accuracy:90.44%
# Epoch 195: iteration 79/80
# Epoch 195 --- loss:0.089, Epoch accuracy:96.22%, Validation loss:0.219, Validation accuracy:91.91%
# Epoch 196: iteration 79/80
# Epoch 196 --- loss:0.062, Epoch accuracy:97.24%, Validation loss:0.160, Validation accuracy:95.59%
# Epoch 197: iteration 79/80
# Epoch 197 --- loss:0.058, Epoch accuracy:97.55%, Validation loss:0.232, Validation accuracy:92.65%
# Epoch 198: iteration 79/80
# Epoch 198 --- loss:0.087, Epoch accuracy:96.30%, Validation loss:0.220, Validation accuracy:91.91%
# Epoch 199: iteration 79/80
# Epoch 199 --- loss:0.038, Epoch accuracy:98.44%, Validation loss:0.163, Validation accuracy:94.12%
# Epoch 200: iteration 79/80
# Epoch 200 --- loss:0.058, Epoch accuracy:97.43%, Validation loss:0.320, Validation accuracy:93.38%
# Epoch 201: iteration 79/80
# Epoch 201 --- loss:0.059, Epoch accuracy:97.59%, Validation loss:0.258, Validation accuracy:93.38%
# Epoch 202: iteration 79/80
# Epoch 202 --- loss:0.047, Epoch accuracy:98.33%, Validation loss:0.194, Validation accuracy:94.12%
# Epoch 203: iteration 79/80
# Epoch 203 --- loss:0.039, Epoch accuracy:98.33%, Validation loss:0.350, Validation accuracy:91.91%
# Epoch 204: iteration 79/80
# Epoch 204 --- loss:0.028, Epoch accuracy:98.48%, Validation loss:0.318, Validation accuracy:94.12%
# Epoch 205: iteration 79/80
# Epoch 205 --- loss:0.061, Epoch accuracy:97.20%, Validation loss:0.150, Validation accuracy:94.85%
# Epoch 206: iteration 79/80
# Epoch 206 --- loss:0.044, Epoch accuracy:98.05%, Validation loss:0.280, Validation accuracy:91.91%
# Epoch 207: iteration 79/80
# Epoch 207 --- loss:0.117, Epoch accuracy:95.33%, Validation loss:0.210, Validation accuracy:90.44%
# Epoch 208: iteration 79/80
# Epoch 208 --- loss:0.061, Epoch accuracy:97.43%, Validation loss:0.178, Validation accuracy:96.32%
# Epoch 209: iteration 79/80
# Epoch 209 --- loss:0.034, Epoch accuracy:98.37%, Validation loss:0.216, Validation accuracy:94.12%
# Epoch 210: iteration 79/80
# Epoch 210 --- loss:0.077, Epoch accuracy:96.73%, Validation loss:0.426, Validation accuracy:92.65%
# Epoch 211: iteration 79/80
# Epoch 211 --- loss:0.044, Epoch accuracy:97.98%, Validation loss:0.177, Validation accuracy:95.59%
# Epoch 212: iteration 79/80
# Epoch 212 --- loss:0.118, Epoch accuracy:95.41%, Validation loss:0.230, Validation accuracy:92.65%
# Epoch 213: iteration 79/80
# Epoch 213 --- loss:0.037, Epoch accuracy:98.48%, Validation loss:0.234, Validation accuracy:90.44%
# Epoch 214: iteration 79/80
# Epoch 214 --- loss:0.047, Epoch accuracy:97.86%, Validation loss:0.307, Validation accuracy:93.38%
# Epoch 215: iteration 79/80
# Epoch 215 --- loss:0.063, Epoch accuracy:97.16%, Validation loss:0.278, Validation accuracy:92.65%
# Epoch 216: iteration 79/80
# Epoch 216 --- loss:0.075, Epoch accuracy:96.81%, Validation loss:0.209, Validation accuracy:94.12%
# Epoch 217: iteration 79/80
# Epoch 217 --- loss:0.083, Epoch accuracy:96.46%, Validation loss:0.294, Validation accuracy:91.91%
# Epoch 218: iteration 79/80
# Epoch 218 --- loss:0.050, Epoch accuracy:97.66%, Validation loss:0.190, Validation accuracy:94.12%
# Epoch 219: iteration 79/80
# Epoch 219 --- loss:0.050, Epoch accuracy:97.98%, Validation loss:0.428, Validation accuracy:88.24%
# Epoch 220: iteration 79/80
# Epoch 220 --- loss:0.070, Epoch accuracy:96.81%, Validation loss:0.221, Validation accuracy:94.12%
# Epoch 221: iteration 79/80
# Epoch 221 --- loss:0.031, Epoch accuracy:98.68%, Validation loss:0.215, Validation accuracy:95.59%
# Epoch 222: iteration 79/80
# Epoch 222 --- loss:0.040, Epoch accuracy:98.33%, Validation loss:0.236, Validation accuracy:94.85%
# Epoch 223: iteration 79/80
# Epoch 223 --- loss:0.084, Epoch accuracy:96.46%, Validation loss:0.204, Validation accuracy:94.12%
# Epoch 224: iteration 79/80
# Epoch 224 --- loss:0.044, Epoch accuracy:98.33%, Validation loss:0.198, Validation accuracy:94.12%
# Epoch 225: iteration 79/80
# Epoch 225 --- loss:0.035, Epoch accuracy:98.44%, Validation loss:0.320, Validation accuracy:91.18%
# Epoch 226: iteration 79/80
# Epoch 226 --- loss:0.057, Epoch accuracy:97.70%, Validation loss:0.265, Validation accuracy:92.65%
# Epoch 227: iteration 79/80
# Epoch 227 --- loss:0.077, Epoch accuracy:97.16%, Validation loss:0.254, Validation accuracy:92.65%
# Epoch 228: iteration 79/80
# Epoch 228 --- loss:0.054, Epoch accuracy:97.51%, Validation loss:0.295, Validation accuracy:94.85%
# Epoch 229: iteration 79/80
# Epoch 229 --- loss:0.027, Epoch accuracy:98.72%, Validation loss:0.268, Validation accuracy:91.91%
# Epoch 230: iteration 79/80
# Epoch 230 --- loss:0.032, Epoch accuracy:98.52%, Validation loss:0.219, Validation accuracy:94.12%
# Epoch 231: iteration 79/80
# Epoch 231 --- loss:0.042, Epoch accuracy:97.94%, Validation loss:0.384, Validation accuracy:92.65%
# Epoch 232: iteration 79/80
# Epoch 232 --- loss:0.079, Epoch accuracy:96.38%, Validation loss:0.207, Validation accuracy:94.12%
# Epoch 233: iteration 79/80
# Epoch 233 --- loss:0.041, Epoch accuracy:98.17%, Validation loss:0.145, Validation accuracy:95.59%
# Epoch 234: iteration 79/80
# Epoch 234 --- loss:0.071, Epoch accuracy:96.96%, Validation loss:0.393, Validation accuracy:93.38%
# Epoch 235: iteration 79/80
# Epoch 235 --- loss:0.056, Epoch accuracy:97.47%, Validation loss:0.198, Validation accuracy:95.59%
# Epoch 236: iteration 79/80
# Epoch 236 --- loss:0.041, Epoch accuracy:98.17%, Validation loss:0.361, Validation accuracy:92.65%
# Epoch 237: iteration 79/80
# Epoch 237 --- loss:0.042, Epoch accuracy:98.13%, Validation loss:0.350, Validation accuracy:91.18%
# Epoch 238: iteration 79/80
# Epoch 238 --- loss:0.062, Epoch accuracy:97.39%, Validation loss:0.404, Validation accuracy:90.44%
# Epoch 239: iteration 79/80
# Epoch 239 --- loss:0.091, Epoch accuracy:96.38%, Validation loss:0.202, Validation accuracy:94.12%
# Epoch 240: iteration 79/80
# Epoch 240 --- loss:0.102, Epoch accuracy:95.68%, Validation loss:0.214, Validation accuracy:91.18%
# Epoch 241: iteration 79/80
# Epoch 241 --- loss:0.047, Epoch accuracy:97.94%, Validation loss:0.110, Validation accuracy:95.59%
# Epoch 242: iteration 79/80
# Epoch 242 --- loss:0.046, Epoch accuracy:98.01%, Validation loss:0.295, Validation accuracy:92.65%
# Epoch 243: iteration 79/80
# Epoch 243 --- loss:0.036, Epoch accuracy:98.37%, Validation loss:0.333, Validation accuracy:90.44%
# Epoch 244: iteration 79/80
# Epoch 244 --- loss:0.100, Epoch accuracy:95.80%, Validation loss:0.287, Validation accuracy:91.91%
# Epoch 245: iteration 79/80
# Epoch 245 --- loss:0.082, Epoch accuracy:96.30%, Validation loss:0.212, Validation accuracy:93.38%
# Epoch 246: iteration 79/80
# Epoch 246 --- loss:0.030, Epoch accuracy:98.56%, Validation loss:0.285, Validation accuracy:92.65%
# Epoch 247: iteration 79/80
# Epoch 247 --- loss:0.054, Epoch accuracy:97.55%, Validation loss:0.171, Validation accuracy:95.59%
# Epoch 248: iteration 79/80
# Epoch 248 --- loss:0.055, Epoch accuracy:97.59%, Validation loss:0.390, Validation accuracy:92.65%
# Epoch 249: iteration 79/80
# Epoch 249 --- loss:0.072, Epoch accuracy:97.08%, Validation loss:0.369, Validation accuracy:91.91%
# Epoch 250: iteration 79/80
# Epoch 250 --- loss:0.099, Epoch accuracy:95.60%, Validation loss:0.196, Validation accuracy:93.38%
# Epoch 251: iteration 79/80
# Epoch 251 --- loss:0.042, Epoch accuracy:97.98%, Validation loss:0.248, Validation accuracy:91.18%
# Epoch 252: iteration 79/80
# Epoch 252 --- loss:0.035, Epoch accuracy:98.29%, Validation loss:0.221, Validation accuracy:95.59%
# Epoch 253: iteration 79/80
# Epoch 253 --- loss:0.039, Epoch accuracy:98.37%, Validation loss:0.215, Validation accuracy:94.12%
# Epoch 254: iteration 79/80
# Epoch 254 --- loss:0.052, Epoch accuracy:97.66%, Validation loss:0.251, Validation accuracy:95.59%
# Epoch 255: iteration 79/80
# Epoch 255 --- loss:0.024, Epoch accuracy:98.64%, Validation loss:0.253, Validation accuracy:91.91%
# Epoch 256: iteration 79/80
# Epoch 256 --- loss:0.038, Epoch accuracy:98.29%, Validation loss:0.264, Validation accuracy:95.59%
# Epoch 257: iteration 79/80
# Epoch 257 --- loss:0.064, Epoch accuracy:97.35%, Validation loss:0.340, Validation accuracy:91.18%
# Epoch 258: iteration 79/80
# Epoch 258 --- loss:0.122, Epoch accuracy:95.06%, Validation loss:0.208, Validation accuracy:93.38%
# Epoch 259: iteration 79/80
# Epoch 259 --- loss:0.047, Epoch accuracy:98.09%, Validation loss:0.278, Validation accuracy:94.12%
# Epoch 260: iteration 79/80
# Epoch 260 --- loss:0.051, Epoch accuracy:97.78%, Validation loss:0.240, Validation accuracy:95.59%
# Epoch 261: iteration 79/80
# Epoch 261 --- loss:0.052, Epoch accuracy:97.74%, Validation loss:0.236, Validation accuracy:94.85%
# Epoch 262: iteration 79/80
# Epoch 262 --- loss:0.056, Epoch accuracy:97.63%, Validation loss:0.204, Validation accuracy:96.32%
# Epoch 263: iteration 79/80
# Epoch 263 --- loss:0.035, Epoch accuracy:98.68%, Validation loss:0.168, Validation accuracy:96.32%
# Epoch 264: iteration 79/80
# Epoch 264 --- loss:0.088, Epoch accuracy:96.19%, Validation loss:0.342, Validation accuracy:93.38%
# Epoch 265: iteration 79/80
# Epoch 265 --- loss:0.064, Epoch accuracy:97.12%, Validation loss:0.353, Validation accuracy:90.44%
# Epoch 266: iteration 79/80
# Epoch 266 --- loss:0.061, Epoch accuracy:97.51%, Validation loss:0.223, Validation accuracy:92.65%
# Epoch 267: iteration 79/80
# Epoch 267 --- loss:0.076, Epoch accuracy:97.08%, Validation loss:0.208, Validation accuracy:91.91%
# Epoch 268: iteration 79/80
# Epoch 268 --- loss:0.031, Epoch accuracy:98.52%, Validation loss:0.247, Validation accuracy:92.65%
# Epoch 269: iteration 79/80
# Epoch 269 --- loss:0.024, Epoch accuracy:98.95%, Validation loss:0.247, Validation accuracy:91.18%
# Epoch 270: iteration 79/80
# Epoch 270 --- loss:0.027, Epoch accuracy:98.91%, Validation loss:0.177, Validation accuracy:91.91%
# Epoch 271: iteration 79/80
# Epoch 271 --- loss:0.020, Epoch accuracy:98.83%, Validation loss:0.279, Validation accuracy:93.38%
# Epoch 272: iteration 79/80
# Epoch 272 --- loss:0.019, Epoch accuracy:98.95%, Validation loss:0.221, Validation accuracy:92.65%
# Epoch 273: iteration 79/80
# Epoch 273 --- loss:0.040, Epoch accuracy:98.17%, Validation loss:0.298, Validation accuracy:92.65%
# Epoch 274: iteration 79/80
# Epoch 274 --- loss:0.126, Epoch accuracy:95.56%, Validation loss:0.363, Validation accuracy:90.44%
# Epoch 275: iteration 79/80
# Epoch 275 --- loss:0.064, Epoch accuracy:97.59%, Validation loss:0.550, Validation accuracy:87.50%
# Epoch 276: iteration 79/80
# Epoch 276 --- loss:0.045, Epoch accuracy:97.98%, Validation loss:0.164, Validation accuracy:96.32%
# Epoch 277: iteration 79/80
# Epoch 277 --- loss:0.029, Epoch accuracy:98.64%, Validation loss:0.339, Validation accuracy:91.91%
# Epoch 278: iteration 79/80
# Epoch 278 --- loss:0.084, Epoch accuracy:96.57%, Validation loss:0.366, Validation accuracy:89.71%
# Epoch 279: iteration 79/80
# Epoch 279 --- loss:0.059, Epoch accuracy:97.20%, Validation loss:0.141, Validation accuracy:94.12%
# Epoch 280: iteration 79/80
# Epoch 280 --- loss:0.065, Epoch accuracy:97.31%, Validation loss:0.274, Validation accuracy:89.71%
# Epoch 281: iteration 79/80
# Epoch 281 --- loss:0.068, Epoch accuracy:97.08%, Validation loss:0.179, Validation accuracy:94.12%
# Epoch 282: iteration 79/80
# Epoch 282 --- loss:0.029, Epoch accuracy:98.79%, Validation loss:0.191, Validation accuracy:94.12%
# Epoch 283: iteration 79/80
# Epoch 283 --- loss:0.040, Epoch accuracy:98.01%, Validation loss:0.179, Validation accuracy:96.32%
# Epoch 284: iteration 79/80
# Epoch 284 --- loss:0.042, Epoch accuracy:98.05%, Validation loss:0.260, Validation accuracy:94.85%
# Epoch 285: iteration 79/80
# Epoch 285 --- loss:0.032, Epoch accuracy:98.40%, Validation loss:0.253, Validation accuracy:94.85%
# Epoch 286: iteration 79/80
# Epoch 286 --- loss:0.128, Epoch accuracy:95.29%, Validation loss:0.267, Validation accuracy:94.12%
# Epoch 287: iteration 79/80
# Epoch 287 --- loss:0.059, Epoch accuracy:97.43%, Validation loss:0.153, Validation accuracy:93.38%
# Epoch 288: iteration 79/80
# Epoch 288 --- loss:0.050, Epoch accuracy:97.98%, Validation loss:0.213, Validation accuracy:94.12%
# Epoch 289: iteration 79/80
# Epoch 289 --- loss:0.040, Epoch accuracy:98.37%, Validation loss:0.231, Validation accuracy:91.91%
# Epoch 290: iteration 79/80
# Epoch 290 --- loss:0.095, Epoch accuracy:96.11%, Validation loss:0.352, Validation accuracy:91.91%
# Epoch 291: iteration 79/80
# Epoch 291 --- loss:0.086, Epoch accuracy:96.50%, Validation loss:0.167, Validation accuracy:94.85%
# Epoch 292: iteration 79/80
# Epoch 292 --- loss:0.047, Epoch accuracy:97.98%, Validation loss:0.249, Validation accuracy:91.18%
# Epoch 293: iteration 79/80
# Epoch 293 --- loss:0.031, Epoch accuracy:98.44%, Validation loss:0.224, Validation accuracy:91.91%
# Epoch 294: iteration 79/80
# Epoch 294 --- loss:0.047, Epoch accuracy:97.94%, Validation loss:0.360, Validation accuracy:91.18%
# Epoch 295: iteration 79/80
# Epoch 295 --- loss:0.066, Epoch accuracy:97.43%, Validation loss:0.167, Validation accuracy:96.32%
# Epoch 296: iteration 79/80
# Epoch 296 --- loss:0.053, Epoch accuracy:97.82%, Validation loss:0.287, Validation accuracy:91.91%
# Epoch 297: iteration 79/80
# Epoch 297 --- loss:0.047, Epoch accuracy:98.17%, Validation loss:0.128, Validation accuracy:97.06%
# Epoch 298: iteration 79/80
# Epoch 298 --- loss:0.043, Epoch accuracy:98.01%, Validation loss:0.355, Validation accuracy:93.38%
# Epoch 299: iteration 79/80
# Epoch 299 --- loss:0.065, Epoch accuracy:97.31%, Validation loss:0.224, Validation accuracy:92.65%
# Epoch 300: iteration 79/80
# Epoch 300 --- loss:0.039, Epoch accuracy:98.01%, Validation loss:0.207, Validation accuracy:94.12%
# Epoch 301: iteration 79/80
# Epoch 301 --- loss:0.026, Epoch accuracy:98.68%, Validation loss:0.254, Validation accuracy:93.38%
# Epoch 302: iteration 79/80
# Epoch 302 --- loss:0.120, Epoch accuracy:95.83%, Validation loss:0.384, Validation accuracy:88.97%
# Epoch 303: iteration 79/80
# Epoch 303 --- loss:0.067, Epoch accuracy:97.31%, Validation loss:0.253, Validation accuracy:94.85%
# Epoch 304: iteration 79/80
# Epoch 304 --- loss:0.033, Epoch accuracy:98.83%, Validation loss:0.186, Validation accuracy:94.12%
# Epoch 305: iteration 79/80
# Epoch 305 --- loss:0.078, Epoch accuracy:96.89%, Validation loss:0.249, Validation accuracy:94.12%
# Epoch 306: iteration 79/80
# Epoch 306 --- loss:0.047, Epoch accuracy:97.70%, Validation loss:0.339, Validation accuracy:90.44%
# Epoch 307: iteration 79/80
# Epoch 307 --- loss:0.056, Epoch accuracy:97.74%, Validation loss:0.221, Validation accuracy:94.12%
# Epoch 308: iteration 79/80
# Epoch 308 --- loss:0.087, Epoch accuracy:96.26%, Validation loss:0.294, Validation accuracy:88.97%
# Epoch 309: iteration 79/80
# Epoch 309 --- loss:0.058, Epoch accuracy:97.35%, Validation loss:0.243, Validation accuracy:92.65%
# Epoch 310: iteration 79/80
# Epoch 310 --- loss:0.083, Epoch accuracy:96.57%, Validation loss:0.233, Validation accuracy:91.91%
# Epoch 311: iteration 79/80
# Epoch 311 --- loss:0.050, Epoch accuracy:97.70%, Validation loss:0.307, Validation accuracy:91.18%
# Epoch 312: iteration 79/80
# Epoch 312 --- loss:0.038, Epoch accuracy:98.09%, Validation loss:0.228, Validation accuracy:94.85%
# Epoch 313: iteration 79/80
# Epoch 313 --- loss:0.038, Epoch accuracy:98.01%, Validation loss:0.165, Validation accuracy:94.85%
# Epoch 314: iteration 79/80
# Epoch 314 --- loss:0.059, Epoch accuracy:97.47%, Validation loss:0.362, Validation accuracy:90.44%
# Epoch 315: iteration 79/80
# Epoch 315 --- loss:0.047, Epoch accuracy:97.90%, Validation loss:0.140, Validation accuracy:97.06%
# Epoch 316: iteration 79/80
# Epoch 316 --- loss:0.054, Epoch accuracy:97.43%, Validation loss:0.316, Validation accuracy:92.65%
# Epoch 317: iteration 79/80
# Epoch 317 --- loss:0.063, Epoch accuracy:97.59%, Validation loss:0.233, Validation accuracy:92.65%
# Epoch 318: iteration 79/80
# Epoch 318 --- loss:0.075, Epoch accuracy:96.77%, Validation loss:0.249, Validation accuracy:94.12%
# Epoch 319: iteration 79/80
# Epoch 319 --- loss:0.045, Epoch accuracy:98.05%, Validation loss:0.419, Validation accuracy:91.91%
# Epoch 320: iteration 79/80
# Epoch 320 --- loss:0.032, Epoch accuracy:98.37%, Validation loss:0.251, Validation accuracy:93.38%
# Epoch 321: iteration 79/80
# Epoch 321 --- loss:0.078, Epoch accuracy:96.81%, Validation loss:0.227, Validation accuracy:94.12%
# Epoch 322: iteration 79/80
# Epoch 322 --- loss:0.044, Epoch accuracy:98.01%, Validation loss:0.476, Validation accuracy:91.18%
# Epoch 323: iteration 79/80
# Epoch 323 --- loss:0.137, Epoch accuracy:94.78%, Validation loss:0.273, Validation accuracy:92.65%
# Epoch 324: iteration 79/80
# Epoch 324 --- loss:0.074, Epoch accuracy:97.00%, Validation loss:0.182, Validation accuracy:94.12%
# Epoch 325: iteration 79/80
# Epoch 325 --- loss:0.064, Epoch accuracy:97.20%, Validation loss:0.181, Validation accuracy:94.12%
# Epoch 326: iteration 79/80
# Epoch 326 --- loss:0.036, Epoch accuracy:98.44%, Validation loss:0.269, Validation accuracy:94.12%
# Epoch 327: iteration 79/80
# Epoch 327 --- loss:0.075, Epoch accuracy:96.92%, Validation loss:0.375, Validation accuracy:92.65%
# Epoch 328: iteration 79/80
# Epoch 328 --- loss:0.030, Epoch accuracy:98.83%, Validation loss:0.281, Validation accuracy:92.65%
# Epoch 329: iteration 79/80
# Epoch 329 --- loss:0.023, Epoch accuracy:98.95%, Validation loss:0.312, Validation accuracy:94.85%
# Epoch 330: iteration 79/80
# Epoch 330 --- loss:0.040, Epoch accuracy:98.09%, Validation loss:0.386, Validation accuracy:90.44%
# Epoch 331: iteration 79/80
# Epoch 331 --- loss:0.123, Epoch accuracy:95.10%, Validation loss:0.220, Validation accuracy:94.12%
# Epoch 332: iteration 79/80
# Epoch 332 --- loss:0.036, Epoch accuracy:98.29%, Validation loss:0.184, Validation accuracy:95.59%
# Epoch 333: iteration 79/80
# Epoch 333 --- loss:0.037, Epoch accuracy:98.17%, Validation loss:0.174, Validation accuracy:94.85%
# Epoch 334: iteration 79/80
# Epoch 334 --- loss:0.024, Epoch accuracy:98.79%, Validation loss:0.258, Validation accuracy:93.38%
# Epoch 335: iteration 79/80
# Epoch 335 --- loss:0.028, Epoch accuracy:98.52%, Validation loss:0.299, Validation accuracy:94.12%
# Epoch 336: iteration 79/80
# Epoch 336 --- loss:0.082, Epoch accuracy:96.61%, Validation loss:0.307, Validation accuracy:94.12%
# Epoch 337: iteration 79/80
# Epoch 337 --- loss:0.068, Epoch accuracy:97.59%, Validation loss:0.241, Validation accuracy:94.12%
# Epoch 338: iteration 79/80
# Epoch 338 --- loss:0.056, Epoch accuracy:97.78%, Validation loss:0.396, Validation accuracy:90.44%
# Epoch 339: iteration 79/80
# Epoch 339 --- loss:0.090, Epoch accuracy:95.99%, Validation loss:0.299, Validation accuracy:89.71%
# Epoch 340: iteration 79/80
# Epoch 340 --- loss:0.054, Epoch accuracy:97.63%, Validation loss:0.439, Validation accuracy:88.24%
# Epoch 341: iteration 79/80
# Epoch 341 --- loss:0.056, Epoch accuracy:97.51%, Validation loss:0.114, Validation accuracy:94.85%
# Epoch 342: iteration 79/80
# Epoch 342 --- loss:0.073, Epoch accuracy:96.85%, Validation loss:0.245, Validation accuracy:93.38%
# Epoch 343: iteration 79/80
# Epoch 343 --- loss:0.064, Epoch accuracy:97.08%, Validation loss:0.275, Validation accuracy:94.12%
# Epoch 344: iteration 79/80
# Epoch 344 --- loss:0.056, Epoch accuracy:97.51%, Validation loss:0.304, Validation accuracy:94.12%
# Epoch 345: iteration 79/80
# Epoch 345 --- loss:0.020, Epoch accuracy:98.95%, Validation loss:0.195, Validation accuracy:93.38%
# Epoch 346: iteration 79/80
# Epoch 346 --- loss:0.034, Epoch accuracy:98.60%, Validation loss:0.321, Validation accuracy:93.38%
# Epoch 347: iteration 79/80
# Epoch 347 --- loss:0.075, Epoch accuracy:96.81%, Validation loss:0.255, Validation accuracy:88.24%
# Epoch 348: iteration 79/80
# Epoch 348 --- loss:0.052, Epoch accuracy:97.55%, Validation loss:0.348, Validation accuracy:91.18%
# Epoch 349: iteration 79/80
# Epoch 349 --- loss:0.030, Epoch accuracy:98.40%, Validation loss:0.299, Validation accuracy:89.71%
# Epoch 350: iteration 79/80
# Epoch 350 --- loss:0.032, Epoch accuracy:98.40%, Validation loss:0.305, Validation accuracy:91.18%
# Epoch 351: iteration 79/80
# Epoch 351 --- loss:0.058, Epoch accuracy:97.70%, Validation loss:0.344, Validation accuracy:92.65%
# Epoch 352: iteration 79/80
# Epoch 352 --- loss:0.059, Epoch accuracy:97.43%, Validation loss:0.331, Validation accuracy:91.91%
# Epoch 353: iteration 79/80
# Epoch 353 --- loss:0.032, Epoch accuracy:98.52%, Validation loss:0.272, Validation accuracy:93.38%
# Epoch 354: iteration 79/80
# Epoch 354 --- loss:0.029, Epoch accuracy:98.60%, Validation loss:0.333, Validation accuracy:92.65%
# Epoch 355: iteration 79/80
# Epoch 355 --- loss:0.112, Epoch accuracy:95.60%, Validation loss:0.189, Validation accuracy:93.38%
# Epoch 356: iteration 79/80
# Epoch 356 --- loss:0.035, Epoch accuracy:98.29%, Validation loss:0.196, Validation accuracy:95.59%
# Epoch 357: iteration 79/80
# Epoch 357 --- loss:0.063, Epoch accuracy:97.04%, Validation loss:0.278, Validation accuracy:91.18%
# Epoch 358: iteration 79/80
# Epoch 358 --- loss:0.101, Epoch accuracy:95.76%, Validation loss:0.324, Validation accuracy:92.65%
# Epoch 359: iteration 79/80
# Epoch 359 --- loss:0.036, Epoch accuracy:98.37%, Validation loss:0.212, Validation accuracy:95.59%
# Epoch 360: iteration 79/80
# Epoch 360 --- loss:0.058, Epoch accuracy:97.39%, Validation loss:0.317, Validation accuracy:92.65%
# Epoch 361: iteration 79/80
# Epoch 361 --- loss:0.042, Epoch accuracy:98.13%, Validation loss:0.171, Validation accuracy:95.59%
# Epoch 362: iteration 79/80
# Epoch 362 --- loss:0.051, Epoch accuracy:97.59%, Validation loss:0.270, Validation accuracy:91.91%
# Epoch 363: iteration 79/80
# Epoch 363 --- loss:0.067, Epoch accuracy:97.35%, Validation loss:0.228, Validation accuracy:91.18%
# Epoch 364: iteration 79/80
# Epoch 364 --- loss:0.064, Epoch accuracy:97.00%, Validation loss:0.130, Validation accuracy:95.59%
# Epoch 365: iteration 79/80
# Epoch 365 --- loss:0.030, Epoch accuracy:98.68%, Validation loss:0.206, Validation accuracy:93.38%
# Epoch 366: iteration 79/80
# Epoch 366 --- loss:0.028, Epoch accuracy:98.64%, Validation loss:0.341, Validation accuracy:90.44%
# Epoch 367: iteration 79/80
# Epoch 367 --- loss:0.117, Epoch accuracy:95.29%, Validation loss:0.221, Validation accuracy:93.38%
# Epoch 368: iteration 79/80
# Epoch 368 --- loss:0.026, Epoch accuracy:98.75%, Validation loss:0.231, Validation accuracy:92.65%
# Epoch 369: iteration 79/80
# Epoch 369 --- loss:0.028, Epoch accuracy:98.60%, Validation loss:0.177, Validation accuracy:94.12%
# Epoch 370: iteration 79/80
# Epoch 370 --- loss:0.039, Epoch accuracy:98.33%, Validation loss:0.224, Validation accuracy:94.12%
# Epoch 371: iteration 79/80
# Epoch 371 --- loss:0.082, Epoch accuracy:96.61%, Validation loss:0.163, Validation accuracy:95.59%
# Epoch 372: iteration 79/80
# ...
# Epoch 373 --- loss:0.068, Epoch accuracy:97.08%, Validation loss:0.231, Validation accuracy:93.38%
# Epoch 374: iteration 79/80
# Epoch 374 --- loss:0.048, Epoch accuracy:97.59%, Validation loss:0.334, Validation accuracy:93.38%
# Epoch 375: iteration 79/80
# Epoch 375 --- loss:0.120, Epoch accuracy:95.37%, Validation loss:0.164, Validation accuracy:94.12%
# Epoch 376: iteration 79/80
# Epoch 376 --- loss:0.045, Epoch accuracy:97.90%, Validation loss:0.204, Validation accuracy:94.85%
# Epoch 377: iteration 79/80
# Epoch 377 --- loss:0.025, Epoch accuracy:98.72%, Validation loss:0.152, Validation accuracy:95.59%
# Epoch 378: iteration 79/80
# Epoch 378 --- loss:0.031, Epoch accuracy:98.44%, Validation loss:0.217, Validation accuracy:94.85%
# Epoch 379: iteration 79/80
# Epoch 379 --- loss:0.072, Epoch accuracy:96.65%, Validation loss:0.331, Validation accuracy:91.18%
# Epoch 380: iteration 79/80
# Epoch 380 --- loss:0.074, Epoch accuracy:96.85%, Validation loss:0.195, Validation accuracy:91.18%
# Epoch 381: iteration 79/80
# Epoch 381 --- loss:0.027, Epoch accuracy:98.87%, Validation loss:0.174, Validation accuracy:94.85%
# Epoch 382: iteration 79/80
# Epoch 382 --- loss:0.058, Epoch accuracy:97.31%, Validation loss:0.324, Validation accuracy:91.91%
# Epoch 383: iteration 79/80
# Epoch 383 --- loss:0.086, Epoch accuracy:96.30%, Validation loss:0.219, Validation accuracy:94.85%
# Epoch 384: iteration 79/80
# Epoch 384 --- loss:0.042, Epoch accuracy:98.17%, Validation loss:0.207, Validation accuracy:93.38%
# Epoch 385: iteration 79/80
# Epoch 385 --- loss:0.025, Epoch accuracy:98.72%, Validation loss:0.298, Validation accuracy:91.91%
# Epoch 386: iteration 79/80
# Epoch 386 --- loss:0.062, Epoch accuracy:96.96%, Validation loss:0.254, Validation accuracy:91.91%
# Epoch 387: iteration 79/80
# Epoch 387 --- loss:0.068, Epoch accuracy:97.24%, Validation loss:0.322, Validation accuracy:93.38%
# Epoch 388: iteration 79/80
# Epoch 388 --- loss:0.078, Epoch accuracy:96.50%, Validation loss:0.357, Validation accuracy:90.44%
# Epoch 389: iteration 79/80
# Epoch 389 --- loss:0.034, Epoch accuracy:98.48%, Validation loss:0.288, Validation accuracy:91.91%
# Epoch 390: iteration 79/80
# Epoch 390 --- loss:0.022, Epoch accuracy:98.79%, Validation loss:0.248, Validation accuracy:94.85%
# Epoch 391: iteration 79/80
# Epoch 391 --- loss:0.057, Epoch accuracy:97.94%, Validation loss:0.235, Validation accuracy:92.65%
# Epoch 392: iteration 79/80
# Epoch 392 --- loss:0.067, Epoch accuracy:97.28%, Validation loss:0.275, Validation accuracy:90.44%
# Epoch 393: iteration 79/80
# Epoch 393 --- loss:0.080, Epoch accuracy:96.92%, Validation loss:0.268, Validation accuracy:94.12%
# Epoch 394: iteration 79/80
# Epoch 394 --- loss:0.038, Epoch accuracy:98.17%, Validation loss:0.317, Validation accuracy:91.91%
# Epoch 395: iteration 79/80
# Epoch 395 --- loss:0.075, Epoch accuracy:96.89%, Validation loss:0.294, Validation accuracy:94.12%
# Epoch 396: iteration 79/80
# Epoch 396 --- loss:0.044, Epoch accuracy:98.09%, Validation loss:0.327, Validation accuracy:91.18%
# Epoch 397: iteration 79/80
# Epoch 397 --- loss:0.045, Epoch accuracy:97.94%, Validation loss:0.419, Validation accuracy:90.44%
# Epoch 398: iteration 79/80
# Epoch 398 --- loss:0.053, Epoch accuracy:97.24%, Validation loss:0.339, Validation accuracy:94.12%
# Epoch 399: iteration 79/80
# Epoch 399 --- loss:0.041, Epoch accuracy:98.37%, Validation loss:0.266, Validation accuracy:92.65%
# Epoch 400: iteration 79/80
# Epoch 400 --- loss:0.041, Epoch accuracy:98.01%, Validation loss:0.225, Validation accuracy:93.38%
# Epoch 401: iteration 79/80
# Epoch 401 --- loss:0.072, Epoch accuracy:96.85%, Validation loss:0.514, Validation accuracy:89.71%
# Epoch 402: iteration 79/80
# Epoch 402 --- loss:0.069, Epoch accuracy:97.12%, Validation loss:0.351, Validation accuracy:90.44%
# Epoch 403: iteration 79/80
# Epoch 403 --- loss:0.105, Epoch accuracy:95.87%, Validation loss:0.239, Validation accuracy:92.65%
# Epoch 404: iteration 79/80
# Epoch 404 --- loss:0.030, Epoch accuracy:98.79%, Validation loss:0.188, Validation accuracy:96.32%
# Epoch 405: iteration 79/80
# Epoch 405 --- loss:0.024, Epoch accuracy:98.83%, Validation loss:0.362, Validation accuracy:93.38%
# Epoch 406: iteration 79/80
# Epoch 406 --- loss:0.108, Epoch accuracy:95.68%, Validation loss:0.198, Validation accuracy:92.65%
# Epoch 407: iteration 79/80
# Epoch 407 --- loss:0.057, Epoch accuracy:97.35%, Validation loss:0.181, Validation accuracy:94.85%
# Epoch 408: iteration 79/80
# Epoch 408 --- loss:0.062, Epoch accuracy:97.24%, Validation loss:0.430, Validation accuracy:90.44%
# Epoch 409: iteration 79/80
# Epoch 409 --- loss:0.063, Epoch accuracy:97.16%, Validation loss:0.227, Validation accuracy:96.32%
# Epoch 410: iteration 79/80
# Epoch 410 --- loss:0.054, Epoch accuracy:97.31%, Validation loss:0.299, Validation accuracy:90.44%
# Epoch 411: iteration 79/80
# Epoch 411 --- loss:0.101, Epoch accuracy:95.99%, Validation loss:0.205, Validation accuracy:93.38%
# Epoch 412: iteration 79/80
# Epoch 412 --- loss:0.035, Epoch accuracy:98.48%, Validation loss:0.287, Validation accuracy:91.91%
# Epoch 413: iteration 79/80
# Epoch 413 --- loss:0.036, Epoch accuracy:98.25%, Validation loss:0.248, Validation accuracy:92.65%
# Epoch 414: iteration 79/80
# Epoch 414 --- loss:0.052, Epoch accuracy:97.86%, Validation loss:0.582, Validation accuracy:87.50%
# Epoch 415: iteration 79/80
# Epoch 415 --- loss:0.051, Epoch accuracy:97.82%, Validation loss:0.323, Validation accuracy:89.71%
# Epoch 416: iteration 79/80
# Epoch 416 --- loss:0.060, Epoch accuracy:97.35%, Validation loss:0.299, Validation accuracy:94.12%
# Epoch 417: iteration 79/80
# Epoch 417 --- loss:0.051, Epoch accuracy:97.78%, Validation loss:0.213, Validation accuracy:94.12%
# Epoch 418: iteration 79/80
# Epoch 418 --- loss:0.067, Epoch accuracy:97.08%, Validation loss:0.217, Validation accuracy:94.12%
# Epoch 419: iteration 79/80
# Epoch 419 --- loss:0.062, Epoch accuracy:97.35%, Validation loss:0.377, Validation accuracy:91.91%
# Epoch 420: iteration 79/80
# Epoch 420 --- loss:0.052, Epoch accuracy:97.74%, Validation loss:0.323, Validation accuracy:91.18%
# Epoch 421: iteration 79/80
# Epoch 421 --- loss:0.062, Epoch accuracy:97.12%, Validation loss:0.273, Validation accuracy:91.18%
# Epoch 422: iteration 79/80
# Epoch 422 --- loss:0.054, Epoch accuracy:97.74%, Validation loss:0.714, Validation accuracy:85.29%
# Epoch 423: iteration 79/80
# Epoch 423 --- loss:0.116, Epoch accuracy:95.48%, Validation loss:0.304, Validation accuracy:94.12%
# Epoch 424: iteration 79/80
# Epoch 424 --- loss:0.036, Epoch accuracy:98.25%, Validation loss:0.288, Validation accuracy:95.59%
# Epoch 425: iteration 79/80
# Epoch 425 --- loss:0.068, Epoch accuracy:97.20%, Validation loss:0.326, Validation accuracy:91.18%
# Epoch 426: iteration 79/80
# Epoch 426 --- loss:0.053, Epoch accuracy:97.74%, Validation loss:0.178, Validation accuracy:94.12%
# Epoch 427: iteration 79/80
# Epoch 427 --- loss:0.070, Epoch accuracy:97.16%, Validation loss:0.145, Validation accuracy:96.32%
# Epoch 428: iteration 79/80
# Epoch 428 --- loss:0.053, Epoch accuracy:97.90%, Validation loss:0.263, Validation accuracy:94.12%
# Epoch 429: iteration 79/80
# Epoch 429 --- loss:0.055, Epoch accuracy:97.51%, Validation loss:0.396, Validation accuracy:91.91%
# Epoch 430: iteration 79/80
# Epoch 430 --- loss:0.070, Epoch accuracy:97.16%, Validation loss:0.158, Validation accuracy:95.59%
# Epoch 431: iteration 79/80
# Epoch 431 --- loss:0.026, Epoch accuracy:98.72%, Validation loss:0.214, Validation accuracy:94.85%
# Epoch 432: iteration 79/80
# Epoch 432 --- loss:0.049, Epoch accuracy:97.74%, Validation loss:0.197, Validation accuracy:95.59%
# Epoch 433: iteration 79/80
# Epoch 433 --- loss:0.035, Epoch accuracy:98.33%, Validation loss:0.343, Validation accuracy:88.97%
# Epoch 434: iteration 79/80
# Epoch 434 --- loss:0.053, Epoch accuracy:97.66%, Validation loss:0.264, Validation accuracy:91.91%
# Epoch 435: iteration 79/80
# Epoch 435 --- loss:0.064, Epoch accuracy:97.08%, Validation loss:0.209, Validation accuracy:95.59%
# Epoch 436: iteration 79/80
# Epoch 436 --- loss:0.026, Epoch accuracy:98.75%, Validation loss:0.250, Validation accuracy:94.12%
# Epoch 437: iteration 79/80
# Epoch 437 --- loss:0.071, Epoch accuracy:96.85%, Validation loss:0.274, Validation accuracy:91.91%
# Epoch 438: iteration 79/80
# Epoch 438 --- loss:0.087, Epoch accuracy:96.42%, Validation loss:0.151, Validation accuracy:94.85%
# Epoch 439: iteration 79/80
# Epoch 439 --- loss:0.024, Epoch accuracy:98.91%, Validation loss:0.246, Validation accuracy:94.85%
# Epoch 440: iteration 79/80
# Epoch 440 --- loss:0.046, Epoch accuracy:97.86%, Validation loss:0.237, Validation accuracy:90.44%
# Epoch 441: iteration 79/80
# Epoch 441 --- loss:0.047, Epoch accuracy:97.94%, Validation loss:0.248, Validation accuracy:92.65%
# Epoch 442: iteration 79/80
# Epoch 442 --- loss:0.075, Epoch accuracy:96.81%, Validation loss:0.287, Validation accuracy:88.24%
# Epoch 443: iteration 79/80
# Epoch 443 --- loss:0.048, Epoch accuracy:97.74%, Validation loss:0.198, Validation accuracy:93.38%
# Epoch 444: iteration 79/80
# Epoch 444 --- loss:0.024, Epoch accuracy:98.79%, Validation loss:0.152, Validation accuracy:95.59%
# Epoch 445: iteration 79/80
# Epoch 445 --- loss:0.110, Epoch accuracy:95.83%, Validation loss:0.172, Validation accuracy:95.59%
# Epoch 446: iteration 79/80
# Epoch 446 --- loss:0.054, Epoch accuracy:97.51%, Validation loss:0.180, Validation accuracy:94.85%
# Epoch 447: iteration 79/80
# Epoch 447 --- loss:0.033, Epoch accuracy:98.56%, Validation loss:0.248, Validation accuracy:92.65%
# Epoch 448: iteration 79/80
# Epoch 448 --- loss:0.030, Epoch accuracy:98.56%, Validation loss:0.422, Validation accuracy:90.44%
# Epoch 449: iteration 79/80
# Epoch 449 --- loss:0.067, Epoch accuracy:96.92%, Validation loss:0.190, Validation accuracy:95.59%
# Epoch 450: iteration 79/80
# Epoch 450 --- loss:0.045, Epoch accuracy:97.98%, Validation loss:0.392, Validation accuracy:92.65%
# Epoch 451: iteration 79/80
# Epoch 451 --- loss:0.057, Epoch accuracy:97.47%, Validation loss:0.416, Validation accuracy:92.65%
# Epoch 452: iteration 79/80
# Epoch 452 --- loss:0.074, Epoch accuracy:96.96%, Validation loss:0.267, Validation accuracy:93.38%
# Epoch 453: iteration 79/80
# Epoch 453 --- loss:0.062, Epoch accuracy:97.20%, Validation loss:0.271, Validation accuracy:91.91%
# Epoch 454: iteration 79/80
# Epoch 454 --- loss:0.062, Epoch accuracy:97.47%, Validation loss:0.159, Validation accuracy:95.59%
# Epoch 455: iteration 79/80
# Epoch 455 --- loss:0.026, Epoch accuracy:98.72%, Validation loss:0.126, Validation accuracy:95.59%
# Epoch 456: iteration 79/80
# Epoch 456 --- loss:0.073, Epoch accuracy:96.81%, Validation loss:0.191, Validation accuracy:94.12%
# Epoch 457: iteration 79/80
# Epoch 457 --- loss:0.040, Epoch accuracy:98.09%, Validation loss:0.270, Validation accuracy:94.12%
# Epoch 458: iteration 79/80
# Epoch 458 --- loss:0.045, Epoch accuracy:97.74%, Validation loss:0.362, Validation accuracy:93.38%
# Epoch 459: iteration 79/80
# Epoch 459 --- loss:0.074, Epoch accuracy:96.65%, Validation loss:0.286, Validation accuracy:91.91%
# Epoch 460: iteration 79/80
# Epoch 460 --- loss:0.027, Epoch accuracy:98.64%, Validation loss:0.217, Validation accuracy:93.38%
# Epoch 461: iteration 79/80
# Epoch 461 --- loss:0.048, Epoch accuracy:97.78%, Validation loss:0.290, Validation accuracy:91.91%
# Epoch 462: iteration 79/80
# Epoch 462 --- loss:0.061, Epoch accuracy:97.63%, Validation loss:0.296, Validation accuracy:92.65%
# Epoch 463: iteration 79/80
# Epoch 463 --- loss:0.052, Epoch accuracy:97.70%, Validation loss:0.227, Validation accuracy:94.12%
# Epoch 464: iteration 79/80
# Epoch 464 --- loss:0.026, Epoch accuracy:98.87%, Validation loss:0.257, Validation accuracy:93.38%
# Epoch 465: iteration 79/80
# Epoch 465 --- loss:0.017, Epoch accuracy:98.95%, Validation loss:0.277, Validation accuracy:94.12%
# Epoch 466: iteration 79/80
# Epoch 466 --- loss:0.018, Epoch accuracy:98.87%, Validation loss:0.267, Validation accuracy:92.65%
# Epoch 467: iteration 79/80
# Epoch 467 --- loss:0.059, Epoch accuracy:97.51%, Validation loss:0.406, Validation accuracy:91.18%
# Epoch 468: iteration 79/80
# Epoch 468 --- loss:0.079, Epoch accuracy:96.81%, Validation loss:0.286, Validation accuracy:92.65%
# Epoch 469: iteration 79/80
# Epoch 469 --- loss:0.083, Epoch accuracy:96.65%, Validation loss:0.541, Validation accuracy:86.03%
# Epoch 470: iteration 79/80
# Epoch 470 --- loss:0.042, Epoch accuracy:98.60%, Validation loss:0.240, Validation accuracy:94.85%
# Epoch 471: iteration 79/80
# Epoch 471 --- loss:0.020, Epoch accuracy:99.07%, Validation loss:0.154, Validation accuracy:96.32%
# Epoch 472: iteration 79/80
# Epoch 472 --- loss:0.025, Epoch accuracy:98.68%, Validation loss:0.153, Validation accuracy:95.59%
# Epoch 473: iteration 79/80
# Epoch 473 --- loss:0.087, Epoch accuracy:96.38%, Validation loss:0.256, Validation accuracy:91.18%
# Epoch 474: iteration 79/80
# Epoch 474 --- loss:0.080, Epoch accuracy:96.46%, Validation loss:0.288, Validation accuracy:93.38%
# Epoch 475: iteration 79/80
# Epoch 475 --- loss:0.064, Epoch accuracy:97.08%, Validation loss:0.503, Validation accuracy:91.18%
# Epoch 476: iteration 79/80
# Epoch 476 --- loss:0.063, Epoch accuracy:97.28%, Validation loss:0.223, Validation accuracy:94.12%
# Epoch 477: iteration 79/80
# Epoch 477 --- loss:0.028, Epoch accuracy:98.52%, Validation loss:0.200, Validation accuracy:94.85%
# Epoch 478: iteration 79/80
# Epoch 478 --- loss:0.049, Epoch accuracy:97.70%, Validation loss:0.210, Validation accuracy:94.12%
# Epoch 479: iteration 79/80
# Epoch 479 --- loss:0.035, Epoch accuracy:98.37%, Validation loss:0.246, Validation accuracy:93.38%
# Epoch 480: iteration 79/80
# Epoch 480 --- loss:0.049, Epoch accuracy:98.05%, Validation loss:0.351, Validation accuracy:93.38%
# Epoch 481: iteration 79/80
# Epoch 481 --- loss:0.053, Epoch accuracy:97.86%, Validation loss:0.386, Validation accuracy:90.44%
# Epoch 482: iteration 79/80
# Epoch 482 --- loss:0.034, Epoch accuracy:98.25%, Validation loss:0.313, Validation accuracy:93.38%
# Epoch 483: iteration 79/80
# Epoch 483 --- loss:0.103, Epoch accuracy:95.52%, Validation loss:0.189, Validation accuracy:94.12%
# Epoch 484: iteration 79/80
# Epoch 484 --- loss:0.033, Epoch accuracy:98.48%, Validation loss:0.371, Validation accuracy:90.44%
# Epoch 485: iteration 79/80
# Epoch 485 --- loss:0.073, Epoch accuracy:96.77%, Validation loss:0.398, Validation accuracy:89.71%
# Epoch 486: iteration 79/80
# Epoch 486 --- loss:0.051, Epoch accuracy:97.94%, Validation loss:0.290, Validation accuracy:91.91%
# Epoch 487: iteration 79/80
# Epoch 487 --- loss:0.026, Epoch accuracy:98.79%, Validation loss:0.329, Validation accuracy:92.65%
# Epoch 488: iteration 79/80
# Epoch 488 --- loss:0.073, Epoch accuracy:97.31%, Validation loss:0.271, Validation accuracy:94.12%
# Epoch 489: iteration 79/80
# Epoch 489 --- loss:0.055, Epoch accuracy:97.70%, Validation loss:0.452, Validation accuracy:92.65%
# Epoch 490: iteration 79/80
# Epoch 490 --- loss:0.057, Epoch accuracy:97.55%, Validation loss:0.300, Validation accuracy:94.12%
# Epoch 491: iteration 79/80
# Epoch 491 --- loss:0.037, Epoch accuracy:98.29%, Validation loss:0.276, Validation accuracy:94.12%
# Epoch 492: iteration 79/80
# Epoch 492 --- loss:0.038, Epoch accuracy:98.05%, Validation loss:0.299, Validation accuracy:91.91%
# Epoch 493: iteration 79/80
# Epoch 493 --- loss:0.026, Epoch accuracy:98.68%, Validation loss:0.216, Validation accuracy:94.85%
# Epoch 494: iteration 79/80
# Epoch 494 --- loss:0.079, Epoch accuracy:96.89%, Validation loss:0.736, Validation accuracy:81.62%
# Epoch 495: iteration 79/80
# Epoch 495 --- loss:0.065, Epoch accuracy:97.35%, Validation loss:0.345, Validation accuracy:91.18%
# Epoch 496: iteration 79/80
# Epoch 496 --- loss:0.032, Epoch accuracy:98.48%, Validation loss:0.239, Validation accuracy:94.12%
# Epoch 497: iteration 79/80
# Epoch 497 --- loss:0.022, Epoch accuracy:98.64%, Validation loss:0.186, Validation accuracy:97.79%
# Epoch 498: iteration 79/80
# Epoch 498 --- loss:0.081, Epoch accuracy:96.81%, Validation loss:0.301, Validation accuracy:91.91%
# Epoch 499: iteration 79/80
# Epoch 499 --- loss:0.034, Epoch accuracy:98.33%, Validation loss:0.283, Validation accuracy:94.12%

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
import os
# pick load folder  
load_folder = 'checkpoint'  

# pick the epoch to load
epoch = '471'
model_name = f'parallel_all_you_wantFINAL-{epoch}.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary 
model = parallel_all_you_want(2)
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from checkpoint\parallel_all_you_wantFINAL-471.pkl

# %%
validate = make_validate_fnc(model,criterion)

X_val = val_x
y_val = val_y
# Convert 4D test feature set array to tensor and move to GPU
X_val_tensor = torch.tensor(X_val,device='cpu').float()
# Convert 4D test label set array to tensor and move to GPU
y_val_tensor = torch.tensor(y_val,dtype=torch.long,device='cpu')

# Get the model's performance metrics using the validation function we defined
_loss, _acc, predicted_emotions = validate(X_val_tensor,y_val_tensor)

print(f'Validation accuracy is {_acc:.2f}%')
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_15788/2725604674.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_val_tensor = torch.tensor(X_val,device='cpu').float()
# C:\Users\Asus\AppData\Local\Temp/ipykernel_15788/2725604674.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_val_tensor = torch.tensor(y_val,dtype=torch.long,device='cpu')
# Validation accuracy is 96.32%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
# because model tested on GPU, move prediction tensor to CPU then convert to array
predicted_emotions = predicted_emotions
# use labels from test set
emotions_groundtruth = y_val

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = ['cc', 'cd']

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()

# %% [markdown]
# ToDo: Make X_Test and Y_Test, Confusion Matrix,

# %%
data_path = 'adress_test.pkl'

X_test,Y_test,_X,_Y = load_data(data_path)
# converting training images into torch format
X_test  = torch.from_numpy(X_test)

# converting the target into torch format

Y_test = Y_test.reshape(Y_test.shape[0]).astype(float);
y_test = torch.from_numpy(Y_test)

# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device='cpu').float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device='cpu')

# Get the model's performance metrics using the validation function we defined
test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)

print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# C:\Users\Asus\AppData\Local\Temp/ipykernel_15788/753559069.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_test_tensor = torch.tensor(X_test,device='cpu').float()
# C:\Users\Asus\AppData\Local\Temp/ipykernel_15788/753559069.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test_tensor = torch.tensor(y_test,dtype=torch.long,device='cpu')
# Test accuracy is 58.61%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
# because model tested on GPU, move prediction tensor to CPU then convert to array
predicted_emotions = predicted_emotions
# use labels from test set
emotions_groundtruth = y_test

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = ['cc', 'cd']

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()
