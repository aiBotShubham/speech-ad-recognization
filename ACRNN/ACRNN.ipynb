# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
data_path = 'IEMOCAP1.pkl'
checkpoint = 'checkpoint/'
model_name = 'model.ckpt'
pred_name = 'pred0.pkl'
checkpoint_secs = 60

dropout_conv = 1
dropout_linear = 1
dropout_lstm = 1
dropout_fully1 = 1
dropout_fully2 = 1

#decayed_learning rate
decay_rate = 0.99
beta1 = 0.9
beta2 = 0.999

#Moving Average
decay_steps = 570
momentum = 0.99
num_epoch = 30000
relu_clip =  20.0

# Adam optimizer (http://arxiv.org/abs/1412.6980) parameters

adam_beta1 = 0.9
adam_beta2 = 0.999
epsilon =  1e-8
learning_rate =   0.0001

# Batch sizes


train_batch_size = 40
valid_batch_size = 40
test_batch_size =  40
batch_size =  40
save_steps =   10

image_height =   300
image_width = 40
image_channel = 3

linear_num =  786
seq_len =   150
cell_num = 128
hidden1 = 64
hidden2 =  4
attention_size =   1
# attention = False

def attention(inputs, attention_size, time_major=False, return_alphas=False):
    """
    Attention mechanism layer which reduces RNN/Bi-RNN outputs with Attention vector.

    The idea was proposed in the article by Z. Yang et al., "Hierarchical Attention Networks
     for Document Classification", 2016: http://www.aclweb.org/anthology/N16-1174.
    Variables notation is also inherited from the article
    
    Args:
        inputs: The Attention inputs.
            Matches outputs of RNN/Bi-RNN layer (not final state):
                In case of RNN, this must be RNN outputs `Tensor`:
                    If time_major == False (default), this must be a tensor of shape:
                        `[batch_size, max_time, cell.output_size]`.
                    If time_major == True, this must be a tensor of shape:
                        `[max_time, batch_size, cell.output_size]`.
                In case of Bidirectional RNN, this must be a tuple (outputs_fw, outputs_bw) containing the forward and
                the backward RNN outputs `Tensor`.
                    If time_major == False (default),
                        outputs_fw is a `Tensor` shaped:
                        `[batch_size, max_time, cell_fw.output_size]`
                        and outputs_bw is a `Tensor` shaped:
                        `[batch_size, max_time, cell_bw.output_size]`.
                    If time_major == True,
                        outputs_fw is a `Tensor` shaped:
                        `[max_time, batch_size, cell_fw.output_size]`
                        and outputs_bw is a `Tensor` shaped:
                        `[max_time, batch_size, cell_bw.output_size]`.
        attention_size: Linear size of the Attention weights.
        time_major: The shape format of the `inputs` Tensors.
            If true, these `Tensors` must be shaped `[max_time, batch_size, depth]`.
            If false, these `Tensors` must be shaped `[batch_size, max_time, depth]`.
            Using `time_major = True` is a bit more efficient because it avoids
            transposes at the beginning and end of the RNN calculation.  However,
            most TensorFlow data is batch-major, so by default this function
            accepts input and emits output in batch-major form.
        return_alphas: Whether to return attention coefficients variable along with layer's output.
            Used for visualization purpose.
    Returns:
        The Attention output `Tensor`.
        In case of RNN, this will be a `Tensor` shaped:
            `[batch_size, cell.output_size]`.
        In case of Bidirectional RNN, this will be a `Tensor` shaped:
            `[batch_size, cell_fw.output_size + cell_bw.output_size]`.
    """

    if isinstance(inputs, tuple):
        # In case of Bi-RNN, concatenate the forward and the backward RNN outputs.
        inputs = tf.concat(inputs, 2)

    if time_major:
        # (T,B,D) => (B,T,D)
        inputs = tf.array_ops.transpose(inputs, [1, 0, 2])

    hidden_size = inputs.shape[2].value  # D value - hidden size of the RNN layer

    # Trainable parameters
    W_omega = tf.Variable(tf.random_normal([hidden_size, attention_size], stddev=0.1))
    b_omega = tf.Variable(tf.random_normal([attention_size], stddev=0.1))
    u_omega = tf.Variable(tf.random_normal([attention_size], stddev=0.1))

    # Applying fully connected layer with non-linear activation to each of the B*T timestamps;
    #  the shape of `v` is (B,T,D)*(D,A)=(B,T,A), where A=attention_size
    #v = tf.tanh(tf.tensordot(inputs, W_omega, axes=1) + b_omega)
    v = tf.sigmoid(tf.tensordot(inputs, W_omega, axes=1) + b_omega)
    # For each of the timestamps its vector of size A from `v` is reduced with `u` vector
    vu = tf.tensordot(v, u_omega, axes=1)   # (B,T) shape
    alphas = tf.nn.softmax(vu)              # (B,T) shape also

    # Output of (Bi-)RNN is reduced with attention vector; the result has (B,D) shape
    output = tf.reduce_sum(inputs * tf.expand_dims(alphas, -1), 1)

    if not return_alphas:
        return output
    else:
        return output, alphas

# %%
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()
tf.disable_v2_behavior()

epsilon = 1e-3

def leaky_relu(x, leakiness=0.0):
    return tf.where(tf.less(x, 0.0), leakiness * x, x, name='leaky_relu')

def batch_norm_wrapper(inputs, is_training, decay = 0.999):

    scale = tf.Variable(tf.ones([inputs.get_shape()[-1]]))
    beta = tf.Variable(tf.zeros([inputs.get_shape()[-1]]))
    pop_mean = tf.Variable(tf.zeros([inputs.get_shape()[-1]]), trainable=False)
    pop_var = tf.Variable(tf.ones([inputs.get_shape()[-1]]), trainable=False)

    if is_training is not None:
        batch_mean, batch_var = tf.nn.moments(inputs,[0])
        train_mean = tf.assign(pop_mean,
                               pop_mean * decay + batch_mean * (1 - decay))
        train_var = tf.assign(pop_var,
                              pop_var * decay + batch_var * (1 - decay))
        with tf.control_dependencies([train_mean, train_var]):
            return tf.nn.batch_normalization(inputs,
                batch_mean, batch_var, beta, scale, epsilon)
    else:
        return tf.nn.batch_normalization(inputs,
            pop_mean, pop_var, beta, scale, epsilon)

def acrnn(inputs, num_classes=4,
                  is_training=True,
                  L1=128,
                  L2=256,
                  cell_units=128,
                  num_linear=768,
                  p=10,
                  time_step=150,
                  F1=64,
                  dropout_keep_prob=1):
    
    global ndims
    layer1_filter = tf.get_variable('layer1_filter', shape=[5, 3, 3, L1], dtype=tf.float32, 
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    layer1_bias = tf.get_variable('layer1_bias', shape=[L1], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer1_stride = [1, 1, 1, 1]
    layer2_filter = tf.get_variable('layer2_filter', shape=[5, 3, L1, L2], dtype=tf.float32, 
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    layer2_bias = tf.get_variable('layer2_bias', shape=[L2], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer2_stride = [1, 1, 1, 1]
    layer3_filter = tf.get_variable('layer3_filter', shape=[5, 3, L2, L2], dtype=tf.float32, 
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    layer3_bias = tf.get_variable('layer3_bias', shape=[L2], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer3_stride = [1, 1, 1, 1]
    layer4_filter = tf.get_variable('layer4_filter', shape=[5, 3, L2, L2], dtype=tf.float32, 
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    layer4_bias = tf.get_variable('layer4_bias', shape=[L2], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer4_stride = [1, 1, 1, 1]
    layer5_filter = tf.get_variable('layer5_filter', shape=[5, 3, L2, L2], dtype=tf.float32, 
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    layer5_bias = tf.get_variable('layer5_bias', shape=[L2], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer5_stride = [1, 1, 1, 1]
    layer6_filter = tf.get_variable('layer6_filter', shape=[5, 3, L2, L2], dtype=tf.float32, 
                                    initializer=tf.compat.v1.truncated_normal_initializer(stddev=0.1))
    layer6_bias = tf.get_variable('layer6_bias', shape=[L2], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    layer6_stride = [1, 1, 1, 1]
    
    linear1_weight = tf.get_variable('linear1_weight', shape=[p*L2,num_linear], dtype=tf.float32,
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    linear1_bias = tf.get_variable('linear1_bias', shape=[num_linear], dtype=tf.float32,
                                  initializer=tf.compat.v1.constant_initializer(0.1))
 
    fully1_weight = tf.get_variable('fully1_weight', shape=[2*cell_units,F1], dtype=tf.float32,
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    fully1_bias = tf.get_variable('fully1_bias', shape=[F1], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    fully2_weight = tf.get_variable('fully2_weight', shape=[F1,num_classes], dtype=tf.float32,
                                    initializer=tf.truncated_normal_initializer(stddev=0.1))
    fully2_bias = tf.get_variable('fully2_bias', shape=[num_classes], dtype=tf.float32,
                                  initializer=tf.constant_initializer(0.1))
    
    layer1 = tf.nn.conv2d(inputs, layer1_filter, layer1_stride, padding='SAME')
    layer1 = tf.nn.bias_add(layer1,layer1_bias)
    layer1 = leaky_relu(layer1, 0.01)
    layer1 = tf.nn.max_pool(layer1,ksize=[1, 2, 4, 1], strides=[1, 2, 4, 1], padding='VALID', name='max_pool')
    layer1 = tf.layers.dropout(layer1, rate = 1 - keep_prob)
    
    layer2 = tf.nn.conv2d(layer1, layer2_filter, layer2_stride, padding='SAME')
    layer2 = tf.nn.bias_add(layer2,layer2_bias)
    layer2 = leaky_relu(layer2, 0.01)
    layer2 = tf.layers.dropout(layer2, rate = 1 - keep_prob)
    
    layer3 = tf.nn.conv2d(layer2, layer3_filter, layer3_stride, padding='SAME')
    layer3 = tf.nn.bias_add(layer3,layer3_bias)
    layer3 = leaky_relu(layer3, 0.01)
    layer3 = tf.layers.dropout(layer3, rate = 1 - keep_prob)
    
    layer4 = tf.nn.conv2d(layer3, layer4_filter, layer4_stride, padding='SAME')
    layer4 = tf.nn.bias_add(layer4,layer4_bias)
    layer4 = leaky_relu(layer4, 0.01)
    layer4 = tf.layers.dropout(layer4, rate = 1 - keep_prob)
    
    layer5 = tf.nn.conv2d(layer4, layer5_filter, layer5_stride, padding='SAME')
    layer5 = tf.nn.bias_add(layer5,layer5_bias)
    layer5 = leaky_relu(layer5, 0.01)    
    layer5 = tf.layers.dropout(layer5, rate = 1 - keep_prob)

    layer6 = tf.nn.conv2d(layer5, layer6_filter, layer6_stride, padding='SAME')
    layer6 = tf.nn.bias_add(layer6,layer6_bias)
    layer6 = leaky_relu(layer6, 0.01)    
    layer6 = tf.layers.dropout(layer6, rate = 1 - keep_prob)
    
    layer6 = tf.reshape(layer6,[-1,time_step,L2*p])
    layer6 = tf.reshape(layer6, [-1,p*L2])
    
    linear1 = tf.matmul(layer6,linear1_weight) + linear1_bias
    linear1 = batch_norm_wrapper(linear1,is_training)
    linear1 = leaky_relu(linear1, 0.01)
    #linear1 = batch_norm_wrapper(linear1,is_training)
    linear1 = tf.reshape(linear1, [-1, time_step, num_linear])
    
    
    
    # Define lstm cells with tensorflow
    # Forward direction cell
    gru_fw_cell1 = tf.nn.rnn_cell.BasicLSTMCell(cell_units, forget_bias=1.0)
    # Backward direction cell
    gru_bw_cell1 = tf.nn.rnn_cell.BasicLSTMCell(cell_units, forget_bias=1.0)
    
    # Now we feed `layer_3` into the LSTM BRNN cell and obtain the LSTM BRNN output.
    outputs1, output_states1 = tf.nn.bidirectional_dynamic_rnn(cell_fw=gru_fw_cell1,
                                                             cell_bw=gru_bw_cell1,
                                                             inputs= linear1,
                                                             dtype=tf.float32,
                                                             time_major=False,
                                                             scope='LSTM1')

    # Attention layer
    gru, alphas = attention(outputs1, 1, return_alphas=True)
    
    
    fully1 = tf.matmul(gru,fully1_weight) + fully1_bias
    fully1 = leaky_relu(fully1, 0.01)
    fully1 = tf.nn.dropout(fully1, dropout_keep_prob)
    
    
    Ylogits = tf.matmul(fully1, fully2_weight) + fully2_bias
    #Ylogits = tf.nn.softmax(Ylogits)
    return Ylogits
# Out:
# WARNING:tensorflow:From C:\Users\SHUBHAM\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def load_data(in_dir):
    f = open(in_dir,'rb')
    train_data,train_label,test_data,test_label,valid_data,valid_label,Valid_label,Test_label,pernums_test,pernums_valid = pickle.load(f)
    return train_data,train_label,test_data,test_label,valid_data,valid_label,Valid_label,Test_label,pernums_test,pernums_valid

def dense_to_one_hot(labels_dense, num_classes):
    """Convert class labels from scalars to one-hot vectors."""
    num_labels = labels_dense.shape[0]
    index_offset = np.arange(num_labels) * num_classes
    labels_one_hot = np.zeros((num_labels, num_classes))
    labels_one_hot.flat[index_offset + labels_dense.ravel()] = 1
    return labels_one_hot

# %%
import numpy as np
import pickle
from sklearn.metrics import recall_score as recall
from sklearn.metrics import confusion_matrix as confusion
import os

num_classes = 4
is_adam = True
dropout_keep_prob = 1
data_path = 'IEMOCAP.pkl'
checkpoint = 'checkpoint/'

train_data,train_label,test_data,test_label,valid_data,valid_label,Valid_label,Test_label,pernums_test,pernums_valid = load_data(data_path)



train_label = dense_to_one_hot(train_label,num_classes)
valid_label = dense_to_one_hot(valid_label,num_classes)
Valid_label = dense_to_one_hot(Valid_label,num_classes)

valid_size = valid_data.shape[0]
dataset_size = train_data.shape[0]
vnum = pernums_valid.shape[0]
best_valid_uw = 0



X = tf.compat.v1.placeholder(tf.float32, shape=[None, image_height,image_width,image_channel])
Y = tf.compat.v1.placeholder(tf.int32, shape=[None, num_classes])

is_training = tf.compat.v1.placeholder(tf.bool)
lr = tf.compat.v1.placeholder(tf.float32)
keep_prob = tf.compat.v1.placeholder(tf.float32)

Ylogits = acrnn(X, is_training=is_training, dropout_keep_prob=keep_prob)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels =  Y, logits =  Ylogits)
cost = tf.reduce_mean(cross_entropy)
var_trainable_op = tf.trainable_variables()
if is_adam:
    # not apply gradient clipping
    train_op = tf.train.AdamOptimizer(lr).minimize(cost)            
else:
    # apply gradient clipping
    grads, _ = tf.clip_by_global_norm(tf.gradients(cost, var_trainable_op), 5)
    opti = tf.train.AdamOptimizer(lr)
    train_op = opti.apply_gradients(zip(grads, var_trainable_op))
    
correct_pred = tf.equal(tf.argmax(Ylogits, 1), tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
saver=tf.train.Saver(tf.global_variables())
init = tf.global_variables_initializer()

epocs = []
validation_accuracy = []
training_accuracy = []
with tf.Session() as sess:
    sess.run(init)
    for i in range(num_epoch):
        #learning_rate = FLAGS.learning_rate            
        start = (i * batch_size) % dataset_size
        end = min(start+batch_size, dataset_size)
        [_,tcost,tracc] = sess.run([train_op,cost,accuracy], feed_dict={X:train_data[start:end,:,:,:], Y:train_label[start:end,:],
                                        is_training:True, keep_prob:dropout_keep_prob, lr:learning_rate})
        if i % 5 == 0:
            #for valid data
            valid_iter = divmod((valid_size),batch_size)[0]
            y_pred_valid = np.empty((valid_size,num_classes),dtype=np.float32)
            y_valid = np.empty((vnum,4),dtype=np.float32)
            index = 0
            cost_valid = 0
            if(valid_size < batch_size):
                loss, y_pred_valid = sess.run([cross_entropy,Ylogits],feed_dict = {X:valid_data, Y:Valid_label,is_training:False, keep_prob:1})
                cost_valid = cost_valid + np.sum(loss)
            for v in range(valid_iter):
                v_begin = v*batch_size
                v_end = (v+1)*batch_size
                if(v == valid_iter-1):
                    if(v_end < valid_size):
                        v_end = valid_size
                loss, y_pred_valid[v_begin:v_end,:] = sess.run([cross_entropy,Ylogits],feed_dict = {X:valid_data[v_begin:v_end],Y:Valid_label[v_begin:v_end],is_training:False, keep_prob:1})
                cost_valid = cost_valid + np.sum(loss)
            cost_valid = cost_valid/valid_size
            
            for s in range(vnum):
                y_valid[s,:] = np.max(y_pred_valid[index:index+pernums_valid[s],:],0)
                index = index + pernums_valid[s]

            valid_acc_uw = recall(np.argmax(valid_label,1),np.argmax(y_valid,1),average='macro')
            valid_conf = confusion(np.argmax(valid_label, 1),np.argmax(y_valid,1))
            
            if valid_acc_uw > best_valid_uw:
                best_valid_uw = valid_acc_uw
                best_valid_conf = valid_conf
                saver.save(sess, os.path.join(checkpoint, model_name), global_step = i+1)
            
            print ("*****************************************************************")
            print ("Epoch: %05d" %(i+1))
            epocs.append(i+1)
            print ("Training cost: %2.3g" %tcost)   
            print ("Training accuracy: %3.4g" %tracc) 
            training_accuracy.append(tracc)
            print ("Valid cost: %2.3g" %cost_valid)
            print ("Valid_UA: %3.4g" %valid_acc_uw) 
            validation_accuracy.append(valid_acc_uw)
            print ("Best valid_UA: %3.4g" %best_valid_uw) 
            print ('Valid Confusion Matrix:["ang","sad","hap","neu"]')
            print (valid_conf)
            print ('Best Valid Confusion Matrix:["ang","sad","hap","neu"]')
            print (best_valid_conf)
            print ("*****************************************************************" )
# Out:
# WARNING:tensorflow:From C:\Users\SHUBHAM\AppData\Local\Temp/ipykernel_16648/2891012328.py:136: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\SHUBHAM\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\ops\rnn.py:438: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\SHUBHAM\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:759: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# C:\Users\SHUBHAM\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\core.py:268: UserWarning: `tf.layers.dropout` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dropout` instead.
#   warnings.warn('`tf.layers.dropout` is deprecated and '
# C:\Users\SHUBHAM\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1692: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# C:\Users\SHUBHAM\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\layers\legacy_rnn\rnn_cell_impl.py:708: UserWarning: `tf.nn.rnn_cell.BasicLSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.BasicLSTMCell` is deprecated and will be "
# C:\Users\SHUBHAM\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# WARNING:tensorflow:From C:\Users\SHUBHAM\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\util\dispatch.py:206: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\SHUBHAM\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\util\dispatch.py:206: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# *****************************************************************
# Epoch: 00001
# Training cost: 1.4
# Training accuracy: 0.225
# Valid cost: 1.35
# Valid_UA: 0.5076
# Best valid_UA: 0.5076
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  1  1  0]
#  [ 2 69  2  0]
#  [14 31 11  0]
#  [30 95 26  0]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  1  1  0]
#  [ 2 69  2  0]
#  [14 31 11  0]
#  [30 95 26  0]]
# *****************************************************************
# *****************************************************************
# Epoch: 00006
# Training cost: 1.16
# Training accuracy: 0.45
# Valid cost: 1.26
# Valid_UA: 0.5663
# Best valid_UA: 0.5663
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 56 12  5]
#  [ 9 14 21 12]
#  [19 56 49 27]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 56 12  5]
#  [ 9 14 21 12]
#  [19 56 49 27]]
# *****************************************************************
# *****************************************************************
# Epoch: 00011
# Training cost: 0.978
# Training accuracy: 0.7
# Valid cost: 1.25
# Valid_UA: 0.5168
# Best valid_UA: 0.5663
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 3 57 11  2]
#  [21 16  9 10]
#  [53 53 26 19]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 56 12  5]
#  [ 9 14 21 12]
#  [19 56 49 27]]
# *****************************************************************
# *****************************************************************
# Epoch: 00016
# Training cost: 1.06
# Training accuracy: 0.475
# Valid cost: 1.16
# Valid_UA: 0.5827
# Best valid_UA: 0.5827
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 49  4 19]
#  [17  7  8 24]
#  [38 25 10 78]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 49  4 19]
#  [17  7  8 24]
#  [38 25 10 78]]
# *****************************************************************
# *****************************************************************
# Epoch: 00021
# Training cost: 0.811
# Training accuracy: 0.725
# Valid cost: 1.09
# Valid_UA: 0.5583
# Best valid_UA: 0.5827
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[14  0  2  2]
#  [ 0 44  3 26]
#  [ 5  8 14 29]
#  [14 24 22 91]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 49  4 19]
#  [17  7  8 24]
#  [38 25 10 78]]
# *****************************************************************
# *****************************************************************
# Epoch: 00026
# Training cost: 0.926
# Training accuracy: 0.6
# Valid cost: 1.17
# Valid_UA: 0.5847
# Best valid_UA: 0.5847
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 2 51  4 16]
#  [15  9 11 21]
#  [35 30 19 67]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 2 51  4 16]
#  [15  9 11 21]
#  [35 30 19 67]]
# *****************************************************************
# *****************************************************************
# Epoch: 00031
# Training cost: 0.926
# Training accuracy: 0.625
# Valid cost: 1.16
# Valid_UA: 0.6157
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00036
# Training cost:  1
# Training accuracy: 0.575
# Valid cost: 1.13
# Valid_UA: 0.5835
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 2 48  6 17]
#  [ 4  6 20 26]
#  [14 24 48 65]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00041
# Training cost: 0.845
# Training accuracy: 0.675
# Valid cost: 1.24
# Valid_UA: 0.5377
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 7 41  4 21]
#  [20  4 10 22]
#  [49 22 18 62]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00046
# Training cost: 0.969
# Training accuracy: 0.55
# Valid cost: 1.23
# Valid_UA: 0.5508
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 3 44  4 22]
#  [18  5 11 22]
#  [52 23 15 61]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00051
# Training cost: 0.658
# Training accuracy: 0.8
# Valid cost: 1.11
# Valid_UA: 0.5518
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[15  0  2  1]
#  [ 4 47  6 16]
#  [ 6  7 19 24]
#  [24 21 47 59]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00056
# Training cost: 0.855
# Training accuracy: 0.675
# Valid cost: 1.16
# Valid_UA: 0.5901
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 49 10 14]
#  [12  8 13 23]
#  [32 25 25 69]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00061
# Training cost: 0.836
# Training accuracy: 0.725
# Valid cost: 1.23
# Valid_UA: 0.5766
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 53  9 10]
#  [15  9 11 21]
#  [38 28 27 58]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00066
# Training cost: 0.981
# Training accuracy: 0.55
# Valid cost: 1.13
# Valid_UA: 0.5793
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 46 10 17]
#  [ 6  7 18 25]
#  [14 23 42 72]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00071
# Training cost: 0.85
# Training accuracy: 0.6
# Valid cost: 1.19
# Valid_UA: 0.5483
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 2 41  7 23]
#  [10  4 16 26]
#  [29 21 32 69]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00076
# Training cost: 0.915
# Training accuracy: 0.7
# Valid cost: 1.27
# Valid_UA: 0.5294
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 3 38  4 28]
#  [20  4  6 26]
#  [46 19 12 74]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00081
# Training cost: 0.568
# Training accuracy: 0.8
# Valid cost: 1.1
# Valid_UA: 0.5562
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[15  0  2  1]
#  [ 2 43  7 21]
#  [ 5  5 16 30]
#  [19 19 35 78]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00086
# Training cost: 0.786
# Training accuracy: 0.7
# Valid cost: 1.12
# Valid_UA: 0.5783
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  1  1]
#  [ 0 53  8 12]
#  [ 8  8 15 25]
#  [22 28 36 65]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00091
# Training cost: 0.77
# Training accuracy: 0.725
# Valid cost: 1.23
# Valid_UA: 0.5901
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 54  9  9]
#  [16  9 14 17]
#  [36 30 29 56]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00096
# Training cost: 0.965
# Training accuracy: 0.6
# Valid cost: 1.14
# Valid_UA: 0.5797
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 49  9 15]
#  [ 8  7 18 23]
#  [19 24 42 66]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00101
# Training cost: 0.792
# Training accuracy: 0.65
# Valid cost: 1.17
# Valid_UA: 0.5501
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 1 42  9 21]
#  [ 9  5 16 26]
#  [26 21 36 68]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00106
# Training cost: 0.874
# Training accuracy: 0.725
# Valid cost: 1.26
# Valid_UA: 0.5278
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 2 38  5 28]
#  [18  5  6 27]
#  [42 20 16 73]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00111
# Training cost: 0.52
# Training accuracy: 0.85
# Valid cost: 1.1
# Valid_UA: 0.5591
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[15  0  2  1]
#  [ 3 43  9 18]
#  [ 6  6 20 24]
#  [20 18 44 69]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00116
# Training cost: 0.751
# Training accuracy: 0.775
# Valid cost: 1.13
# Valid_UA: 0.581
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  1  1]
#  [ 1 52  9 11]
#  [11  9 16 20]
#  [24 27 34 66]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00121
# Training cost: 0.712
# Training accuracy: 0.7
# Valid cost: 1.2
# Valid_UA: 0.5933
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 2 53  9  9]
#  [13  9 14 20]
#  [34 29 28 60]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00126
# Training cost: 0.919
# Training accuracy: 0.6
# Valid cost: 1.13
# Valid_UA: 0.5642
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 45  8 20]
#  [ 8  5 15 28]
#  [21 21 36 73]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00131
# Training cost: 0.721
# Training accuracy: 0.65
# Valid cost: 1.22
# Valid_UA: 0.5553
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 2 44  9 18]
#  [11  5 14 26]
#  [29 23 35 64]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00136
# Training cost: 0.85
# Training accuracy: 0.7
# Valid cost: 1.24
# Valid_UA: 0.5497
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 2 40  7 24]
#  [15  5  9 27]
#  [39 19 19 74]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00141
# Training cost: 0.457
# Training accuracy: 0.85
# Valid cost: 1.09
# Valid_UA: 0.556
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[15  0  2  1]
#  [ 2 39 14 18]
#  [ 4  6 22 24]
#  [14 15 52 70]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00146
# Training cost: 0.701
# Training accuracy: 0.775
# Valid cost: 1.12
# Valid_UA: 0.5905
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  0  1]
#  [ 1 47 10 15]
#  [10  6 17 23]
#  [25 24 31 71]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00151
# Training cost: 0.659
# Training accuracy: 0.725
# Valid cost: 1.17
# Valid_UA: 0.5983
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 53  9 10]
#  [13  9 14 20]
#  [30 28 30 63]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00156
# Training cost: 0.871
# Training accuracy: 0.675
# Valid cost: 1.13
# Valid_UA: 0.5819
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 2 43 12 16]
#  [ 6  5 22 23]
#  [19 19 44 69]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00161
# Training cost: 0.623
# Training accuracy: 0.7
# Valid cost: 1.25
# Valid_UA: 0.577
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 2 45  9 17]
#  [13  6 15 22]
#  [34 20 33 64]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00166
# Training cost: 0.799
# Training accuracy: 0.775
# Valid cost: 1.2
# Valid_UA: 0.5815
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 2 46  7 18]
#  [13  6 13 24]
#  [36 20 25 70]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00171
# Training cost: 0.431
# Training accuracy: 0.85
# Valid cost: 1.12
# Valid_UA: 0.5633
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[15  0  2  1]
#  [ 1 39 18 15]
#  [ 5  6 24 21]
#  [16 14 52 69]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00176
# Training cost: 0.651
# Training accuracy: 0.8
# Valid cost: 1.12
# Valid_UA: 0.5958
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 44 12 16]
#  [ 9  6 17 24]
#  [24 25 30 72]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00181
# Training cost: 0.575
# Training accuracy: 0.8
# Valid cost: 1.14
# Valid_UA: 0.6034
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 53 10  9]
#  [ 9  9 17 21]
#  [22 31 40 58]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00186
# Training cost: 0.812
# Training accuracy: 0.725
# Valid cost: 1.21
# Valid_UA: 0.5546
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 1 40 15 17]
#  [ 9  6 23 18]
#  [22 15 58 56]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00191
# Training cost: 0.517
# Training accuracy: 0.8
# Valid cost: 1.22
# Valid_UA: 0.589
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 47 12 13]
#  [ 9  7 18 22]
#  [31 23 38 59]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00196
# Training cost: 0.735
# Training accuracy: 0.775
# Valid cost: 1.17
# Valid_UA: 0.594
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 44 10 19]
#  [10  6 14 26]
#  [28 16 28 79]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00201
# Training cost: 0.333
# Training accuracy: 0.925
# Valid cost: 1.17
# Valid_UA: 0.5744
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[15  0  2  1]
#  [ 0 45 18 10]
#  [ 9  8 23 16]
#  [16 18 51 66]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00206
# Training cost: 0.566
# Training accuracy: 0.8
# Valid cost: 1.1
# Valid_UA: 0.586
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 48 13 12]
#  [ 7  8 13 28]
#  [17 25 32 77]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00211
# Training cost: 0.512
# Training accuracy: 0.8
# Valid cost: 1.24
# Valid_UA: 0.5503
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 1 43 15 14]
#  [12  6 17 21]
#  [25 24 47 55]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00216
# Training cost: 0.721
# Training accuracy: 0.775
# Valid cost: 1.12
# Valid_UA: 0.5694
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 40 14 19]
#  [ 4  5 20 27]
#  [13 15 50 73]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00221
# Training cost: 0.402
# Training accuracy: 0.9
# Valid cost: 1.3
# Valid_UA: 0.5507
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 42 15 16]
#  [15  5 14 22]
#  [38 22 34 57]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00226
# Training cost: 0.677
# Training accuracy: 0.825
# Valid cost: 1.18
# Valid_UA: 0.5792
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  0  1]
#  [ 1 42 20 10]
#  [10  4 22 20]
#  [21 14 55 61]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00231
# Training cost: 0.301
# Training accuracy: 0.925
# Valid cost: 1.23
# Valid_UA: 0.5696
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 41 21 11]
#  [ 8  5 23 20]
#  [17 13 58 63]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00236
# Training cost: 0.559
# Training accuracy: 0.775
# Valid cost: 1.11
# Valid_UA: 0.5851
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 56 10  7]
#  [ 7 10 10 29]
#  [21 34 28 68]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00241
# Training cost: 0.465
# Training accuracy: 0.875
# Valid cost: 1.27
# Valid_UA: 0.5523
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 47 13 13]
#  [12  7 14 23]
#  [32 20 43 56]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00246
# Training cost: 0.702
# Training accuracy: 0.725
# Valid cost: 1.21
# Valid_UA: 0.5366
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 30 10 33]
#  [ 7  2 17 30]
#  [21 10 38 82]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00251
# Training cost: 0.319
# Training accuracy: 0.925
# Valid cost: 1.21
# Valid_UA: 0.5732
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 42  7 23]
#  [13  7 12 24]
#  [32 23 20 76]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00256
# Training cost: 0.549
# Training accuracy: 0.85
# Valid cost: 1.29
# Valid_UA: 0.5895
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 33 21 18]
#  [ 8  2 27 19]
#  [20  9 58 64]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00261
# Training cost: 0.296
# Training accuracy: 0.95
# Valid cost: 1.16
# Valid_UA: 0.6028
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  0  1]
#  [ 0 42 13 18]
#  [ 9  6 21 20]
#  [19 14 40 78]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00266
# Training cost: 0.466
# Training accuracy: 0.825
# Valid cost: 1.06
# Valid_UA: 0.5894
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 49 10 14]
#  [ 7  6 13 30]
#  [16 26 32 77]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00271
# Training cost: 0.405
# Training accuracy: 0.9
# Valid cost: 1.34
# Valid_UA: 0.5396
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 46 19  8]
#  [17  9 14 16]
#  [42 27 40 42]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00276
# Training cost: 0.63
# Training accuracy: 0.775
# Valid cost: 1.13
# Valid_UA: 0.5674
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 40 10 23]
#  [ 5  4 14 33]
#  [12 12 39 88]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00281
# Training cost: 0.28
# Training accuracy: 0.975
# Valid cost: 1.28
# Valid_UA: 0.5533
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 44 10 19]
#  [18  8  6 24]
#  [37 19 19 76]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00286
# Training cost: 0.466
# Training accuracy: 0.875
# Valid cost: 1.2
# Valid_UA: 0.55
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[15  0  2  1]
#  [ 0 40 19 14]
#  [ 6  2 21 27]
#  [10 11 63 67]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00291
# Training cost: 0.237
# Training accuracy: 0.975
# Valid cost: 1.26
# Valid_UA: 0.5668
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 39 10 24]
#  [12  4 11 29]
#  [29 12 29 81]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00296
# Training cost: 0.367
# Training accuracy: 0.9
# Valid cost: 1.18
# Valid_UA: 0.5677
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 53 12  8]
#  [ 8 12 13 23]
#  [ 9 31 47 64]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00301
# Training cost: 0.403
# Training accuracy: 0.875
# Valid cost: 1.4
# Valid_UA: 0.5483
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 51 14  7]
#  [17 10 11 18]
#  [39 30 37 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00306
# Training cost: 0.559
# Training accuracy: 0.8
# Valid cost: 1.32
# Valid_UA: 0.5458
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 32 11 30]
#  [ 6  2 19 29]
#  [24  8 41 78]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00311
# Training cost: 0.225
# Training accuracy:   1
# Valid cost: 1.3
# Valid_UA: 0.5491
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 48 11 14]
#  [16  8 12 20]
#  [40 32 30 49]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00316
# Training cost: 0.489
# Training accuracy: 0.8
# Valid cost: 1.2
# Valid_UA: 0.5773
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 43 17 13]
#  [ 9  6 14 27]
#  [15 17 48 71]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00321
# Training cost: 0.221
# Training accuracy: 0.95
# Valid cost: 1.23
# Valid_UA: 0.566
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 32 10 31]
#  [12  3 11 30]
#  [23  9 24 95]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00326
# Training cost: 0.27
# Training accuracy: 0.925
# Valid cost: 1.33
# Valid_UA: 0.5556
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[15  0  3  0]
#  [ 0 44 18 11]
#  [ 8  7 24 17]
#  [10 22 65 54]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00331
# Training cost: 0.302
# Training accuracy: 0.925
# Valid cost: 1.33
# Valid_UA: 0.5738
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 53  8 12]
#  [11 12 12 21]
#  [27 36 26 62]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00336
# Training cost: 0.611
# Training accuracy: 0.8
# Valid cost: 1.55
# Valid_UA: 0.5426
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 40  8 25]
#  [15  4 14 23]
#  [31 11 36 73]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00341
# Training cost: 0.265
# Training accuracy: 0.95
# Valid cost: 1.28
# Valid_UA: 0.5682
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  0  1]
#  [ 0 43 11 19]
#  [10  7 11 28]
#  [21 17 31 82]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00346
# Training cost: 0.409
# Training accuracy: 0.825
# Valid cost: 1.48
# Valid_UA: 0.5621
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 1 51 19  2]
#  [11 11 25  9]
#  [33 28 66 24]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00351
# Training cost: 0.121
# Training accuracy:   1
# Valid cost: 1.27
# Valid_UA: 0.5101
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[15  0  2  1]
#  [ 0 29  8 36]
#  [ 6  2  9 39]
#  [16  7 30 98]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00356
# Training cost: 0.361
# Training accuracy: 0.9
# Valid cost: 1.37
# Valid_UA: 0.5357
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  1  1]
#  [ 0 45 14 14]
#  [14  7  9 26]
#  [28 18 33 72]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00361
# Training cost: 0.356
# Training accuracy: 0.85
# Valid cost: 1.39
# Valid_UA: 0.5556
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 53 12  8]
#  [12 11 12 21]
#  [21 37 42 51]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00366
# Training cost: 0.517
# Training accuracy: 0.75
# Valid cost: 1.43
# Valid_UA: 0.5752
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 45 10 18]
#  [15  5 14 22]
#  [28 17 32 74]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00371
# Training cost: 0.282
# Training accuracy: 0.925
# Valid cost: 1.48
# Valid_UA: 0.5568
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 36 13 24]
#  [10  4 21 21]
#  [26 12 42 71]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00376
# Training cost: 0.496
# Training accuracy: 0.85
# Valid cost: 1.54
# Valid_UA: 0.5523
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 43 12 18]
#  [19  5 11 21]
#  [42 17 28 64]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00381
# Training cost: 0.199
# Training accuracy: 0.875
# Valid cost: 1.26
# Valid_UA: 0.5527
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[15  0  2  1]
#  [ 0 40 20 13]
#  [ 3  5 19 29]
#  [10 15 52 74]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00386
# Training cost: 0.357
# Training accuracy: 0.875
# Valid cost: 1.64
# Valid_UA: 0.5265
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 41  6 25]
#  [23  5  6 22]
#  [48 18 19 66]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00391
# Training cost: 0.234
# Training accuracy: 0.925
# Valid cost: 1.58
# Valid_UA: 0.5758
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 49 18  6]
#  [ 5  9 29 13]
#  [11 30 76 34]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00396
# Training cost: 0.39
# Training accuracy: 0.85
# Valid cost: 1.26
# Valid_UA: 0.5606
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  0  1]
#  [ 0 44 10 19]
#  [10  6 10 30]
#  [24 17 32 78]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00401
# Training cost: 0.137
# Training accuracy: 0.975
# Valid cost: 1.83
# Valid_UA: 0.5209
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [20 11 17  8]
#  [44 22 54 31]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00406
# Training cost: 0.253
# Training accuracy: 0.975
# Valid cost: 1.36
# Valid_UA: 0.5582
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  0  1]
#  [ 0 42  8 23]
#  [12  9 11 24]
#  [26 21 26 78]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00411
# Training cost: 0.0888
# Training accuracy: 0.975
# Valid cost: 1.77
# Valid_UA: 0.5477
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 34 33  6]
#  [13  4 30  9]
#  [21 12 81 37]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00416
# Training cost: 0.202
# Training accuracy: 0.95
# Valid cost: 1.21
# Valid_UA: 0.5918
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  1  1]
#  [ 0 53  7 13]
#  [ 7  8  8 33]
#  [14 25 20 92]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00421
# Training cost: 0.204
# Training accuracy: 0.95
# Valid cost: 1.5
# Valid_UA: 0.5775
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 55 10  8]
#  [15  9 17 15]
#  [28 32 36 55]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00426
# Training cost: 0.225
# Training accuracy: 0.95
# Valid cost: 1.54
# Valid_UA: 0.5455
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 33 18 22]
#  [ 9  4 23 20]
#  [17 12 57 65]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00431
# Training cost: 0.109
# Training accuracy:   1
# Valid cost: 1.46
# Valid_UA: 0.5739
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 48 14 11]
#  [14  9 14 19]
#  [29 23 32 67]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00436
# Training cost: 0.247
# Training accuracy: 0.925
# Valid cost: 1.63
# Valid_UA: 0.5467
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 47 18  8]
#  [17  8 12 19]
#  [36 23 34 58]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00441
# Training cost: 0.059
# Training accuracy:   1
# Valid cost: 1.53
# Valid_UA: 0.5497
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 33 20 20]
#  [10  4 16 26]
#  [21  9 43 78]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00446
# Training cost: 0.146
# Training accuracy: 0.95
# Valid cost: 1.42
# Valid_UA: 0.5559
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[15  0  2  1]
#  [ 0 45 19  9]
#  [ 9  8 17 22]
#  [12 19 49 71]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00451
# Training cost: 0.148
# Training accuracy: 0.95
# Valid cost: 1.67
# Valid_UA: 0.5535
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 59 11  3]
#  [14 16 11 15]
#  [35 42 34 40]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00456
# Training cost: 0.179
# Training accuracy: 0.95
# Valid cost: 1.56
# Valid_UA: 0.5631
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 46 11 16]
#  [13  7 10 26]
#  [31 20 33 67]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00461
# Training cost: 0.0743
# Training accuracy:   1
# Valid cost: 1.63
# Valid_UA: 0.5411
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[16  0  2  0]
#  [ 0 40 14 19]
#  [10  7 17 22]
#  [22 17 48 64]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00466
# Training cost: 0.126
# Training accuracy: 0.975
# Valid cost: 1.81
# Valid_UA: 0.5516
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 0 51 15  7]
#  [16  9 11 20]
#  [38 26 40 47]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00471
# Training cost: 0.0366
# Training accuracy:   1
# Valid cost: 1.6
# Valid_UA: 0.5314
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 39 22 12]
#  [12  5 11 28]
#  [21 18 44 68]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 00476
# Training cost: 0.116
# Training accuracy: 0.95
# Valid cost: 1.49
# ...
# Valid_UA: 0.5373
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [14  9 14 19]
#  [25 25 52 49]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01036
# Training cost: 0.00642
# Training accuracy:   1
# Valid cost: 2.31
# Valid_UA: 0.534
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [14  9 14 19]
#  [26 25 53 47]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01041
# Training cost: 0.00229
# Training accuracy:   1
# Valid cost: 2.34
# Valid_UA: 0.534
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [14  9 14 19]
#  [26 25 53 47]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01046
# Training cost: 0.00548
# Training accuracy:   1
# Valid cost: 2.35
# Valid_UA: 0.5306
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [14  9 14 19]
#  [26 26 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01051
# Training cost: 0.00316
# Training accuracy:   1
# Valid cost: 2.36
# Valid_UA: 0.5306
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [14  9 14 19]
#  [26 26 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01056
# Training cost: 0.0042
# Training accuracy:   1
# Valid cost: 2.36
# Valid_UA: 0.5351
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [13  9 15 19]
#  [26 26 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01061
# Training cost: 0.00189
# Training accuracy:   1
# Valid cost: 2.37
# Valid_UA: 0.5351
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [13  9 15 19]
#  [25 26 55 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01066
# Training cost: 0.00545
# Training accuracy:   1
# Valid cost: 2.38
# Valid_UA: 0.5341
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 47 15 11]
#  [14  8 14 20]
#  [26 26 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01071
# Training cost: 0.00198
# Training accuracy:   1
# Valid cost: 2.38
# Valid_UA: 0.5341
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 47 15 11]
#  [14  8 14 20]
#  [26 26 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01076
# Training cost: 0.0047
# Training accuracy:   1
# Valid cost: 2.38
# Valid_UA: 0.5341
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 47 15 11]
#  [14  8 14 20]
#  [26 26 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01081
# Training cost: 0.00274
# Training accuracy:   1
# Valid cost: 2.38
# Valid_UA: 0.5272
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 45 17 11]
#  [14  8 14 20]
#  [26 26 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01086
# Training cost: 0.00366
# Training accuracy:   1
# Valid cost: 2.38
# Valid_UA: 0.5317
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 45 17 11]
#  [13  8 15 20]
#  [25 26 55 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01091
# Training cost: 0.00168
# Training accuracy:   1
# Valid cost: 2.39
# Valid_UA: 0.5351
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [13  8 15 20]
#  [24 26 56 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01096
# Training cost: 0.00475
# Training accuracy:   1
# Valid cost: 2.4
# Valid_UA: 0.5306
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [14  8 14 20]
#  [25 26 55 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01101
# Training cost: 0.00178
# Training accuracy:   1
# Valid cost: 2.4
# Valid_UA: 0.5306
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [14  8 14 20]
#  [27 26 53 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01106
# Training cost: 0.00418
# Training accuracy:   1
# Valid cost: 2.41
# Valid_UA: 0.5306
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [14  8 14 20]
#  [28 25 53 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01111
# Training cost: 0.00244
# Training accuracy:   1
# Valid cost: 2.41
# Valid_UA: 0.5306
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [14  8 14 20]
#  [27 25 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01116
# Training cost: 0.00318
# Training accuracy:   1
# Valid cost: 2.42
# Valid_UA: 0.5351
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [13  8 15 20]
#  [25 26 55 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01121
# Training cost: 0.0015
# Training accuracy:   1
# Valid cost: 2.43
# Valid_UA: 0.5351
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [13  8 15 20]
#  [25 26 55 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01126
# Training cost: 0.00421
# Training accuracy:   1
# Valid cost: 2.43
# Valid_UA: 0.5351
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [13  8 15 20]
#  [25 26 55 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01131
# Training cost: 0.00162
# Training accuracy:   1
# Valid cost: 2.44
# Valid_UA: 0.5306
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [14  8 14 20]
#  [27 25 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01136
# Training cost: 0.00373
# Training accuracy:   1
# Valid cost: 2.44
# Valid_UA: 0.5306
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 16 11]
#  [14  8 14 20]
#  [27 25 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01141
# Training cost: 0.0022
# Training accuracy:   1
# Valid cost: 2.44
# Valid_UA: 0.5351
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 17 10]
#  [13  8 15 20]
#  [26 25 55 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01146
# Training cost: 0.00281
# Training accuracy:   1
# Valid cost: 2.45
# Valid_UA: 0.5351
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 17 10]
#  [13  8 15 20]
#  [25 26 55 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01151
# Training cost: 0.00136
# Training accuracy:   1
# Valid cost: 2.46
# Valid_UA: 0.5396
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 17 10]
#  [13  7 16 20]
#  [25 26 55 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01156
# Training cost: 0.00373
# Training accuracy:   1
# Valid cost: 2.46
# Valid_UA: 0.5396
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 17 10]
#  [13  7 16 20]
#  [25 26 55 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01161
# Training cost: 0.00149
# Training accuracy:   1
# Valid cost: 2.46
# Valid_UA: 0.5396
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 17 10]
#  [13  7 16 20]
#  [27 25 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# *****************************************************************
# Epoch: 01166
# Training cost: 0.00337
# Training accuracy:   1
# Valid cost: 2.46
# Valid_UA: 0.5396
# Best valid_UA: 0.6157
# Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[17  0  1  0]
#  [ 0 46 17 10]
#  [13  7 16 20]
#  [27 25 54 45]]
# Best Valid Confusion Matrix:["ang","sad","hap","neu"]
# [[18  0  0  0]
#  [ 1 55  6 11]
#  [11  9 16 20]
#  [28 30 29 64]]
# *****************************************************************
# --------------------
# KeyboardInterruptTraceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16648/1470311615.py in <module>
#      60         start = (i * batch_size) % dataset_size
#      61         end = min(start+batch_size, dataset_size)
# ---> 62         [_,tcost,tracc] = sess.run([train_op,cost,accuracy], feed_dict={X:train_data[start:end,:,:,:], Y:train_label[start:end,:],
#      63                                         is_training:True, keep_prob:dropout_keep_prob, lr:learning_rate})
#      64         if i % 5 == 0:
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     965
#     966     try:
# --> 967       result = self._run(None, fetches, feed_dict, options_ptr,
#     968                          run_metadata_ptr)
#     969       if run_metadata:
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1188     # or if the call is a partial run that specifies feeds.
#    1189     if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1190       results = self._do_run(handle, final_targets, final_fetches,
#    1191                              feed_dict_tensor, options, run_metadata)
#    1192     else:
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1366
#    1367     if handle is None:
# -> 1368       return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1369                            run_metadata)
#    1370     else:
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1373   def _do_call(self, fn, *args):
#    1374     try:
# -> 1375       return fn(*args)
#    1376     except errors.OpError as e:
#    1377       message = compat.as_text(e.message)
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1357       # Ensure any changes to the graph are reflected in the runtime.
#    1358       self._extend_graph()
# -> 1359       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1360                                       target_list, run_metadata)
#    1361
#
# ~\anaconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1449   def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1450                           run_metadata):
# -> 1451     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1452                                             fetch_list, target_list,
#    1453                                             run_metadata)
#
# KeyboardInterrupt:

# %%
import seaborn as sns
import matplotlib.pyplot as plt     

ax= plt.subplot()
sns.heatmap(best_valid_conf, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells, ftm='g' to disable scientific notation

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(["ang","sad","hap","neu"]); ax.yaxis.set_ticklabels(["ang","sad","hap","neu"]);

# %%
import matplotlib.pyplot as plt
import numpy as np
  
# define data values
x = epocs  # X-axis points
y = validation_accuracy  # Y-axis points
z =   training_accuracy
plt.plot(x, y, 'red')
plt.plot(x, z, 'blue') # Plot the chart
plt.legend(["validation", "training"], loc ="lower right")
plt.show()  # display

# %%
# define data values
x = epocs  # X-axis points
y = validation_accuracy  # Y-axis points
  
plt.plot(x, y)  # Plot the chart
plt.show()  # display
